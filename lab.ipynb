# %% [markdown]
# # Lab 11

# %% [markdown]
# ## Connect to DBMS

# %%
from pymongo import MongoClient
client = MongoClient("mongodb://localhost")
collection = client['test']['restaurants']

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# ### Query all Indian cuisines

# %%
collection.find({'cuisine': 'Indian'})

# %% [markdown]
# To show data we can use `list()` or `for`. Then, I'm going to use `list()`.

# %%
list(collection.find({'cuisine': 'Indian'}))
# Out:
# [{'_id': ObjectId('626675eb1b3fa6fbc408ce8b'),
#   'address': {'building': '320',
#    'coord': [-73.977597, 40.779593],
#    'street': 'Columbus Avenue',
#    'zipcode': '10023'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 10, 27, 0, 0),
#     'grade': 'A',
#     'score': 7},
#    {'date': datetime.datetime(2013, 7, 29, 0, 0), 'grade': 'A', 'score': 5},
#    {'date': datetime.datetime(2013, 2, 19, 0, 0), 'grade': 'A', 'score': 11},
#    {'date': datetime.datetime(2012, 1, 12, 0, 0), 'grade': 'A', 'score': 2}],
#   'name': 'Mughlai Restaurant',
#   'restaurant_id': '40370243'},
#  {'_id': ObjectId('626675eb1b3fa6fbc408cef2'),
#   'address': {'building': '807',
#    'coord': [-73.96643449999999, 40.7641697],
#    'street': 'Lexington Avenue',
#    'zipcode': '10065'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 10, 28, 0, 0),
#     'grade': 'A',
#     'score': 10},
#    {'date': datetime.datetime(2014, 7, 9, 0, 0), 'grade': 'B', 'score': 24},
#    {'date': datetime.datetime(2014, 1, 17, 0, 0), 'grade': 'A', 'score': 11},
#    {'date': datetime.datetime(2013, 5, 28, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2012, 3, 27, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2011, 11, 2, 0, 0), 'grade': 'C', 'score': 28}],
#   'name': 'Agra Restaurant',
#   'restaurant_id': '40375376'},
#  {'_id': ObjectId('626675eb1b3fa6fbc408cf4d'),
#   'address': {'building': '8443',
#    'coord': [-73.80112059999999, 40.7128278],
#    'street': '164 Street',
#    'zipcode': '11432'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 11, 28, 0, 0),
#     'grade': 'A',
#     'score': 4},
#    {'date': datetime.datetime(2014, 6, 16, 0, 0), 'grade': 'A', 'score': 8},
#    {'date': datetime.datetime(2013, 5, 15, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 5, 29, 0, 0), 'grade': 'A', 'score': 13}],
#   'name': 'Annam Braham Restaurant',
#   'restaurant_id': '40380520'},
#  {'_id': ObjectId('626675eb1b3fa6fbc408cf5a'),
#   'address': {'building': '345',
#    'coord': [-73.9864626, 40.7266739],
#    'street': 'East 6 Street',
#    'zipcode': '10003'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 9, 15, 0, 0),
#     'grade': 'A',
#     'score': 5},
#    {'date': datetime.datetime(2014, 1, 14, 0, 0), 'grade': 'A', 'score': 8},
#    {'date': datetime.datetime(2013, 5, 30, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2013, 4, 24, 0, 0), 'grade': 'P', 'score': 2},
#    {'date': datetime.datetime(2012, 10, 1, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2012, 4, 6, 0, 0), 'grade': 'C', 'score': 92},
#    {'date': datetime.datetime(2011, 11, 3, 0, 0), 'grade': 'C', 'score': 41}],
#   'name': 'Gandhi',
#   'restaurant_id': '40381295'},
#  {'_id': ObjectId('626675eb1b3fa6fbc408cf95'),
#   'address': {'building': '7407',
#    'coord': [-74.0272951, 40.6318285],
#    'street': '3 Avenue',
#    'zipcode': '11209'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 12, 17, 0, 0),
#     'grade': 'Z',
#     'score': 15},
#    {'date': datetime.datetime(2014, 6, 19, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2013, 10, 2, 0, 0), 'grade': 'B', 'score': 16},
#    {'date': datetime.datetime(2013, 4, 15, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2012, 7, 23, 0, 0), 'grade': 'A', 'score': 6},
#    {'date': datetime.datetime(2011, 12, 20, 0, 0), 'grade': 'A', 'score': 12}],
#   'name': 'India Passage Restaurant',
#   'restaurant_id': '40384479'},
#  {'_id': ObjectId('626675eb1b3fa6fbc408d04a'),
#   'address': {'building': '100',
#    'coord': [-73.988342, 40.727111],
#    'street': 'Second Avenue',
#    'zipcode': '10003'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 11, 24, 0, 0),
#     'grade': 'A',
#     'score': 12},
#    {'date': datetime.datetime(2014, 4, 21, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2013, 3, 1, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2012, 2, 15, 0, 0), 'grade': 'A', 'score': 12}],
#   'name': 'Haveli',
#   'restaurant_id': '40390209'},
#  {'_id': ObjectId('626675eb1b3fa6fbc408d055'),
#   'address': {'building': '287',
#    'coord': [-74.1126424, 40.5722235],
#    'street': 'Newdorp Ln',
#    'zipcode': '10306'},
#   'borough': 'Staten Island',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 6, 20, 0, 0),
#     'grade': 'A',
#     'score': 4},
#    {'date': datetime.datetime(2013, 5, 21, 0, 0), 'grade': 'A', 'score': 10},
#    {'date': datetime.datetime(2012, 5, 8, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2011, 12, 22, 0, 0), 'grade': 'A', 'score': 12}],
#   'name': 'Taste Of India Ii Restaurant',
#   'restaurant_id': '40390536'},
#  {'_id': ObjectId('626675eb1b3fa6fbc408d0ef'),
#   'address': {'building': '148',
#    'coord': [-73.983139, 40.759967],
#    'street': 'West   49 Street',
#    'zipcode': '10019'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 9, 22, 0, 0),
#     'grade': 'A',
#     'score': 9},
#    {'date': datetime.datetime(2014, 5, 12, 0, 0), 'grade': 'A', 'score': 10},
#    {'date': datetime.datetime(2013, 11, 4, 0, 0), 'grade': 'A', 'score': 5},
#    {'date': datetime.datetime(2013, 2, 25, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2012, 7, 5, 0, 0), 'grade': 'A', 'score': 11},
#    {'date': datetime.datetime(2011, 11, 25, 0, 0), 'grade': 'B', 'score': 15}],
#   'name': 'Bombay Masala',
#   'restaurant_id': '40394066'},
#  {'_id': ObjectId('626675eb1b3fa6fbc408d12d'),
#   'address': {'building': '357',
#    'coord': [-73.96642899999999, 40.754211],
#    'street': 'East 50 Street',
#    'zipcode': '10022'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 4, 24, 0, 0),
#     'grade': 'A',
#     'score': 11},
#    {'date': datetime.datetime(2013, 10, 22, 0, 0), 'grade': 'A', 'score': 6},
#    {'date': datetime.datetime(2013, 4, 3, 0, 0), 'grade': 'A', 'score': 11},
#    {'date': datetime.datetime(2012, 7, 23, 0, 0), 'grade': 'B', 'score': 21},
#    {'date': datetime.datetime(2011, 10, 13, 0, 0), 'grade': 'B', 'score': 15}],
#   'name': 'Indigo Indian Cuisine',
#   'restaurant_id': '40395748'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d1a2'),
#   'address': {'building': '119',
#    'coord': [-73.982139, 40.742638],
#    'street': 'Lexington Avenue',
#    'zipcode': '10016'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 10, 15, 0, 0),
#     'grade': 'A',
#     'score': 12},
#    {'date': datetime.datetime(2014, 4, 14, 0, 0), 'grade': 'B', 'score': 15},
#    {'date': datetime.datetime(2013, 10, 23, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2013, 4, 8, 0, 0), 'grade': 'B', 'score': 19},
#    {'date': datetime.datetime(2012, 10, 19, 0, 0), 'grade': 'B', 'score': 26},
#    {'date': datetime.datetime(2012, 5, 23, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2011, 12, 30, 0, 0), 'grade': 'C', 'score': 37}],
#   'name': 'Curry In A Hurry',
#   'restaurant_id': '40398434'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d26e'),
#   'address': {'building': '27',
#    'coord': [-74.00892689999999, 40.7133533],
#    'street': 'Park Place',
#    'zipcode': '10007'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 12, 11, 0, 0),
#     'grade': 'Z',
#     'score': 15},
#    {'date': datetime.datetime(2014, 4, 10, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2013, 10, 9, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2013, 7, 16, 0, 0), 'grade': 'P', 'score': 5},
#    {'date': datetime.datetime(2012, 7, 16, 0, 0), 'grade': 'A', 'score': 11},
#    {'date': datetime.datetime(2012, 1, 18, 0, 0), 'grade': 'A', 'score': 8}],
#   'name': 'Bangal Curry',
#   'restaurant_id': '40401972'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d2bb'),
#   'address': {'building': '4',
#    'coord': [-73.7822056, 40.6434612],
#    'street': '- Jfk Airport',
#    'zipcode': '11430'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 7, 22, 0, 0),
#     'grade': 'B',
#     'score': 27},
#    {'date': datetime.datetime(2013, 6, 7, 0, 0), 'grade': 'A', 'score': 5},
#    {'date': datetime.datetime(2012, 6, 22, 0, 0), 'grade': 'A', 'score': 2}],
#   'name': 'Air India Lounge',
#   'restaurant_id': '40403419'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d348'),
#   'address': {'building': '409',
#    'coord': [-73.98021000000001, 40.7423],
#    'street': '3 Avenue',
#    'zipcode': '10016'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 2, 12, 0, 0),
#     'grade': 'A',
#     'score': 8},
#    {'date': datetime.datetime(2013, 5, 29, 0, 0), 'grade': 'A', 'score': 0},
#    {'date': datetime.datetime(2012, 5, 22, 0, 0), 'grade': 'A', 'score': 3},
#    {'date': datetime.datetime(2012, 1, 5, 0, 0), 'grade': 'A', 'score': 4},
#    {'date': datetime.datetime(2011, 5, 18, 0, 0), 'grade': 'B', 'score': 18}],
#   'name': 'Vatan',
#   'restaurant_id': '40513757'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d363'),
#   'address': {'building': '104',
#    'coord': [-73.98302199999999, 40.742313],
#    'street': 'Lexington Avenue',
#    'zipcode': '10016'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 10, 15, 0, 0),
#     'grade': 'A',
#     'score': 9},
#    {'date': datetime.datetime(2013, 9, 25, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2013, 5, 7, 0, 0), 'grade': 'A', 'score': 7},
#    {'date': datetime.datetime(2012, 4, 16, 0, 0), 'grade': 'A', 'score': 2},
#    {'date': datetime.datetime(2011, 11, 28, 0, 0), 'grade': 'B', 'score': 15}],
#   'name': 'Madras Mahal',
#   'restaurant_id': '40519978'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d38a'),
#   'address': {'building': '2628',
#    'coord': [-90.6220568, 37.76564],
#    'street': 'Cedar Street',
#    'zipcode': '10005'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 9, 22, 0, 0),
#     'grade': 'A',
#     'score': 2},
#    {'date': datetime.datetime(2013, 10, 3, 0, 0), 'grade': 'A', 'score': 0},
#    {'date': datetime.datetime(2013, 4, 24, 0, 0), 'grade': 'A', 'score': 4},
#    {'date': datetime.datetime(2012, 2, 9, 0, 0), 'grade': 'A', 'score': 4}],
#   'name': 'Diwan-E-Khaas',
#   'restaurant_id': '40527369'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d399'),
#   'address': {'building': '15403',
#    'coord': [-73.8096901, 40.72001729999999],
#    'street': 'Union Turnpike',
#    'zipcode': '11367'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 12, 1, 0, 0),
#     'grade': 'A',
#     'score': 5},
#    {'date': datetime.datetime(2013, 11, 7, 0, 0), 'grade': 'A', 'score': 3},
#    {'date': datetime.datetime(2012, 9, 12, 0, 0), 'grade': 'A', 'score': 7}],
#   'name': 'Khyber Restaurant',
#   'restaurant_id': '40530409'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d3a7'),
#   'address': {'building': '1237',
#    'coord': [-73.9586465, 40.8097342],
#    'street': 'Amsterdam Avenue',
#    'zipcode': '10027'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 8, 5, 0, 0),
#     'grade': 'A',
#     'score': 10},
#    {'date': datetime.datetime(2014, 2, 5, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 12, 15, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2011, 11, 23, 0, 0), 'grade': 'A', 'score': 12}],
#   'name': 'Ajanta India',
#   'restaurant_id': '40534837'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d3aa'),
#   'address': {'building': '322',
#    'coord': [-73.9874971, 40.7267605],
#    'street': 'East    6 Street',
#    'zipcode': '10003'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 12, 1, 0, 0),
#     'grade': 'A',
#     'score': 12},
#    {'date': datetime.datetime(2014, 3, 25, 0, 0), 'grade': 'B', 'score': 20},
#    {'date': datetime.datetime(2013, 7, 22, 0, 0), 'grade': 'A', 'score': 7},
#    {'date': datetime.datetime(2013, 1, 24, 0, 0), 'grade': 'A', 'score': 4},
#    {'date': datetime.datetime(2012, 4, 17, 0, 0), 'grade': 'A', 'score': 12}],
#   'name': 'Raj Mahal Indian Restaurant',
#   'restaurant_id': '40534870'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d3f3'),
#   'address': {'building': '110',
#    'coord': [-73.98289749999999, 40.7424602],
#    'street': 'Lexington Avenue',
#    'zipcode': '10016'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 1, 9, 0, 0),
#     'grade': 'A',
#     'score': 13},
#    {'date': datetime.datetime(2013, 5, 8, 0, 0), 'grade': 'A', 'score': 6},
#    {'date': datetime.datetime(2012, 10, 9, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2012, 5, 16, 0, 0), 'grade': 'C', 'score': 11}],
#   'name': 'Pongal Indian Cuisine',
#   'restaurant_id': '40544107'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d45b'),
#   'address': {'building': '603',
#    'coord': [-73.93709729999999, 40.8554247],
#    'street': 'Fort Washington Avenue',
#    'zipcode': '10040'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 8, 18, 0, 0),
#     'grade': 'A',
#     'score': 12},
#    {'date': datetime.datetime(2014, 3, 27, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2013, 2, 21, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 8, 27, 0, 0), 'grade': 'A', 'score': 13}],
#   'name': 'Kismat Indian Cuisine',
#   'restaurant_id': '40557912'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d4d4'),
#   'address': {'building': '257-05',
#    'coord': [-73.7142688, 40.7458682],
#    'street': 'Union Turnpike',
#    'zipcode': '11004'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2015, 1, 7, 0, 0),
#     'grade': 'Z',
#     'score': 24},
#    {'date': datetime.datetime(2014, 6, 30, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2014, 1, 29, 0, 0), 'grade': 'A', 'score': 11},
#    {'date': datetime.datetime(2013, 6, 22, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2013, 1, 3, 0, 0), 'grade': 'C', 'score': 49},
#    {'date': datetime.datetime(2012, 5, 3, 0, 0), 'grade': 'B', 'score': 16},
#    {'date': datetime.datetime(2012, 4, 20, 0, 0), 'grade': 'P', 'score': 5}],
#   'name': 'Santoor Indian Restaurant',
#   'restaurant_id': '40571663'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d5bd'),
#   'address': {'building': '53',
#    'coord': [-74.0091352, 40.7090346],
#    'street': 'Nassau Street',
#    'zipcode': '10005'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 3, 19, 0, 0),
#     'grade': 'A',
#     'score': 2},
#    {'date': datetime.datetime(2013, 2, 26, 0, 0), 'grade': 'A', 'score': 3},
#    {'date': datetime.datetime(2011, 12, 2, 0, 0), 'grade': 'A', 'score': 10},
#    {'date': datetime.datetime(2011, 7, 11, 0, 0), 'grade': 'A', 'score': 4}],
#   'name': 'Diwan-E- Khaas',
#   'restaurant_id': '40598366'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d5c6'),
#   'address': {'building': '2906',
#    'coord': [-73.92431599999999, 40.75651879999999],
#    'street': '36 Avenue',
#    'zipcode': '11106'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 9, 11, 0, 0),
#     'grade': 'A',
#     'score': 11},
#    {'date': datetime.datetime(2013, 10, 1, 0, 0), 'grade': 'A', 'score': 8},
#    {'date': datetime.datetime(2012, 10, 23, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2011, 10, 28, 0, 0), 'grade': 'A', 'score': 10}],
#   'name': 'Aladdin',
#   'restaurant_id': '40601254'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d622'),
#   'address': {'building': '8306',
#    'coord': [-73.82961499999999, 40.708951],
#    'street': 'Austin Street',
#    'zipcode': '11415'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 2, 8, 0, 0),
#     'grade': 'A',
#     'score': 12},
#    {'date': datetime.datetime(2013, 7, 24, 0, 0), 'grade': 'A', 'score': 7},
#    {'date': datetime.datetime(2012, 12, 18, 0, 0), 'grade': 'A', 'score': 7},
#    {'date': datetime.datetime(2012, 6, 6, 0, 0), 'grade': 'A', 'score': 11}],
#   'name': 'Mehak',
#   'restaurant_id': '40615240'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d6a0'),
#   'address': {'building': '3747',
#    'coord': [-73.8913291, 40.7477727],
#    'street': '74 Street',
#    'zipcode': '11372'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 8, 27, 0, 0),
#     'grade': 'B',
#     'score': 16},
#    {'date': datetime.datetime(2013, 12, 9, 0, 0), 'grade': 'B', 'score': 17},
#    {'date': datetime.datetime(2013, 6, 6, 0, 0), 'grade': 'B', 'score': 19},
#    {'date': datetime.datetime(2012, 12, 6, 0, 0), 'grade': 'C', 'score': 0},
#    {'date': datetime.datetime(2012, 5, 23, 0, 0), 'grade': 'B', 'score': 22},
#    {'date': datetime.datetime(2011, 10, 27, 0, 0), 'grade': 'B', 'score': 23}],
#   'name': 'Jackson Diner Indian Cuisine',
#   'restaurant_id': '40647953'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d705'),
#   'address': {'building': '706-8',
#    'coord': [-73.9714858, 40.793109],
#    'street': 'Amsterdam Avenue',
#    'zipcode': '10025'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 7, 21, 0, 0),
#     'grade': 'A',
#     'score': 5},
#    {'date': datetime.datetime(2013, 6, 13, 0, 0), 'grade': 'A', 'score': 11},
#    {'date': datetime.datetime(2012, 12, 27, 0, 0), 'grade': 'A', 'score': 10},
#    {'date': datetime.datetime(2012, 2, 2, 0, 0), 'grade': 'B', 'score': 17}],
#   'name': 'Ayurveda Cafe',
#   'restaurant_id': '40666541'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d72b'),
#   'address': {'building': '5',
#    'coord': [-73.98641099999999, 40.746979],
#    'street': 'West   31 Street',
#    'zipcode': '10001'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 9, 9, 0, 0),
#     'grade': 'A',
#     'score': 9},
#    {'date': datetime.datetime(2014, 4, 8, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2013, 10, 3, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2013, 4, 23, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2012, 6, 28, 0, 0), 'grade': 'B', 'score': 27},
#    {'date': datetime.datetime(2012, 1, 30, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2011, 10, 3, 0, 0), 'grade': 'B', 'score': 25}],
#   'name': 'Minar Indian Restaurant',
#   'restaurant_id': '40672926'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d7a4'),
#   'address': {'building': '283',
#    'coord': [-74.0032824, 40.7319341],
#    'street': 'Bleecker Street',
#    'zipcode': '10014'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 7, 31, 0, 0),
#     'grade': 'A',
#     'score': 9},
#    {'date': datetime.datetime(2013, 7, 30, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2013, 3, 6, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 7, 12, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 2, 10, 0, 0), 'grade': 'B', 'score': 14},
#    {'date': datetime.datetime(2011, 9, 21, 0, 0), 'grade': 'A', 'score': 10}],
#   'name': 'Ghandi Cafe',
#   'restaurant_id': '40703670'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d805'),
#   'address': {'building': '4563',
#    'coord': [-73.816634, 40.7524508],
#    'street': 'Bowne Street',
#    'zipcode': '11355'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2015, 1, 7, 0, 0),
#     'grade': 'A',
#     'score': 3},
#    {'date': datetime.datetime(2014, 8, 4, 0, 0), 'grade': 'A', 'score': 11},
#    {'date': datetime.datetime(2013, 12, 9, 0, 0), 'grade': 'B', 'score': 19},
#    {'date': datetime.datetime(2013, 6, 28, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2012, 6, 12, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2012, 1, 18, 0, 0), 'grade': 'A', 'score': 11}],
#   'name': 'Dosa Hutt',
#   'restaurant_id': '40718547'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d827'),
#   'address': {'building': '1845',
#    'coord': [-73.9825829, 40.769461],
#    'street': 'Broadway',
#    'zipcode': '10023'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 8, 30, 0, 0),
#     'grade': 'A',
#     'score': 13},
#    {'date': datetime.datetime(2014, 3, 27, 0, 0), 'grade': 'C', 'score': 36},
#    {'date': datetime.datetime(2013, 6, 10, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 3, 12, 0, 0), 'grade': 'A', 'score': 13}],
#   'name': 'Sapphire Indian Cuisine',
#   'restaurant_id': '40722258'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d84f'),
#   'address': {'building': '1185',
#    'coord': [-73.9824347, 40.7578271],
#    'street': 'Avenue Of Americas',
#    'zipcode': '10036'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 12, 11, 0, 0),
#     'grade': 'A',
#     'score': 12},
#    {'date': datetime.datetime(2013, 10, 15, 0, 0), 'grade': 'A', 'score': 8},
#    {'date': datetime.datetime(2013, 5, 3, 0, 0), 'grade': 'A', 'score': 11},
#    {'date': datetime.datetime(2012, 8, 16, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 3, 8, 0, 0), 'grade': 'A', 'score': 12}],
#   'name': 'Utsav Festive India Restaurant',
#   'restaurant_id': '40727750'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d91a'),
#   'address': {'building': '63-108',
#    'coord': [-73.8671967, 40.7216631],
#    'street': 'Woodhaven Boulevard',
#    'zipcode': '11374'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 2, 22, 0, 0),
#     'grade': 'A',
#     'score': 10},
#    {'date': datetime.datetime(2013, 5, 2, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 6, 14, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2011, 12, 15, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2011, 7, 12, 0, 0), 'grade': 'C', 'score': 30}],
#   'name': 'Maurya Restaurant',
#   'restaurant_id': '40754126'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d926'),
#   'address': {'building': '7315',
#    'coord': [-74.0271258, 40.6323596],
#    'street': '3 Avenue',
#    'zipcode': '11209'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 12, 10, 0, 0),
#     'grade': 'A',
#     'score': 5},
#    {'date': datetime.datetime(2013, 11, 27, 0, 0), 'grade': 'A', 'score': 11},
#    {'date': datetime.datetime(2013, 6, 12, 0, 0), 'grade': 'A', 'score': 7},
#    {'date': datetime.datetime(2012, 10, 16, 0, 0), 'grade': 'A', 'score': 8},
#    {'date': datetime.datetime(2012, 4, 16, 0, 0), 'grade': 'A', 'score': 10}],
#   'name': 'Taj Mahal Indian Restaurant',
#   'restaurant_id': '40756209'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d9ad'),
#   'address': {'building': '',
#    'coord': [-73.97705599999999, 40.752998],
#    'street': 'Grand Central Terminal',
#    'zipcode': '10017'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 5, 19, 0, 0),
#     'grade': 'A',
#     'score': 9},
#    {'date': datetime.datetime(2013, 12, 11, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2013, 6, 5, 0, 0), 'grade': 'A', 'score': 11},
#    {'date': datetime.datetime(2012, 4, 30, 0, 0), 'grade': 'A', 'score': 10},
#    {'date': datetime.datetime(2011, 12, 19, 0, 0), 'grade': 'A', 'score': 10},
#    {'date': datetime.datetime(2011, 6, 15, 0, 0), 'grade': 'B', 'score': 16}],
#   'name': 'Cafe Spice',
#   'restaurant_id': '40793607'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d9b7'),
#   'address': {'building': '310',
#    'coord': [-73.9881162, 40.7269427],
#    'street': 'East    6 Street',
#    'zipcode': '10003'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 6, 3, 0, 0),
#     'grade': 'A',
#     'score': 5},
#    {'date': datetime.datetime(2013, 10, 18, 0, 0), 'grade': 'A', 'score': 7},
#    {'date': datetime.datetime(2013, 2, 12, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2011, 10, 25, 0, 0), 'grade': 'A', 'score': 2}],
#   'name': 'Taj Cafe',
#   'restaurant_id': '40793198'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d9e3'),
#   'address': {'building': '68',
#    'coord': [-73.9968939, 40.7236789],
#    'street': 'Prince Street',
#    'zipcode': '10012'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 4, 25, 0, 0),
#     'grade': 'A',
#     'score': 7},
#    {'date': datetime.datetime(2013, 4, 10, 0, 0), 'grade': 'A', 'score': 7},
#    {'date': datetime.datetime(2012, 3, 14, 0, 0), 'grade': 'A', 'score': 8},
#    {'date': datetime.datetime(2011, 8, 12, 0, 0), 'grade': 'A', 'score': 12}],
#   'name': 'Hampton Chutney Company',
#   'restaurant_id': '40802900'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408da05'),
#   'address': {'building': '87-46',
#    'coord': [-73.8030423, 40.7081423],
#    'street': 'Parsons Boulevard',
#    'zipcode': '11432'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 9, 24, 0, 0),
#     'grade': 'Z',
#     'score': 22},
#    {'date': datetime.datetime(2014, 5, 15, 0, 0), 'grade': 'A', 'score': 10},
#    {'date': datetime.datetime(2013, 11, 13, 0, 0), 'grade': 'A', 'score': 7},
#    {'date': datetime.datetime(2013, 5, 31, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 12, 20, 0, 0), 'grade': 'A', 'score': 10},
#    {'date': datetime.datetime(2011, 11, 23, 0, 0), 'grade': 'A', 'score': 13}],
#   'name': 'Al-Mehran Restaurant',
#   'restaurant_id': '40810032'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408da61'),
#   'address': {'building': '3725',
#    'coord': [-73.8914324, 40.7482588],
#    'street': '74 Street',
#    'zipcode': '11372'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 4, 25, 0, 0),
#     'grade': 'A',
#     'score': 12},
#    {'date': datetime.datetime(2013, 9, 18, 0, 0), 'grade': 'A', 'score': 10},
#    {'date': datetime.datetime(2013, 2, 12, 0, 0), 'grade': 'B', 'score': 15},
#    {'date': datetime.datetime(2012, 7, 17, 0, 0), 'grade': 'A', 'score': 7},
#    {'date': datetime.datetime(2012, 7, 5, 0, 0), 'grade': 'P', 'score': 13},
#    {'date': datetime.datetime(2012, 2, 8, 0, 0), 'grade': 'B', 'score': 19}],
#   'name': 'Indian Taj',
#   'restaurant_id': '40827157'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408da66'),
#   'address': {'building': '34-14',
#    'coord': [-73.91863839999999, 40.7653613],
#    'street': '30 Avenue',
#    'zipcode': '11103'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 8, 19, 0, 0),
#     'grade': 'A',
#     'score': 5},
#    {'date': datetime.datetime(2014, 1, 29, 0, 0), 'grade': 'A', 'score': 10},
#    {'date': datetime.datetime(2012, 12, 31, 0, 0), 'grade': 'A', 'score': 10},
#    {'date': datetime.datetime(2012, 7, 12, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2011, 11, 23, 0, 0), 'grade': 'A', 'score': 9}],
#   'name': 'Gandhi Indian Cuisine',
#   'restaurant_id': '40827726'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408da7f'),
#   'address': {'building': '45-57',
#    'coord': [-73.8169913, 40.7528258],
#    'street': 'Bowne Street',
#    'zipcode': '11355'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 4, 23, 0, 0),
#     'grade': 'A',
#     'score': 13},
#    {'date': datetime.datetime(2013, 3, 28, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 10, 26, 0, 0), 'grade': 'A', 'score': 5},
#    {'date': datetime.datetime(2012, 3, 9, 0, 0), 'grade': 'B', 'score': 17},
#    {'date': datetime.datetime(2011, 10, 27, 0, 0), 'grade': 'B', 'score': 23}],
#   'name': 'Devasthanam Canteen',
#   'restaurant_id': '40835821'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408da80'),
#   'address': {'building': '73-10',
#    'coord': [-73.8923799, 40.7488892],
#    'street': '37 Avenue',
#    'zipcode': '11372'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2015, 1, 6, 0, 0),
#     'grade': 'Z',
#     'score': 18},
#    {'date': datetime.datetime(2014, 7, 9, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2014, 1, 31, 0, 0), 'grade': 'A', 'score': 5},
#    {'date': datetime.datetime(2013, 8, 23, 0, 0), 'grade': 'A', 'score': 7},
#    {'date': datetime.datetime(2013, 3, 20, 0, 0), 'grade': 'C', 'score': 33},
#    {'date': datetime.datetime(2012, 9, 25, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 4, 17, 0, 0), 'grade': 'A', 'score': 13}],
#   'name': 'Maharaja Quality Sweets',
#   'restaurant_id': '40836314'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408db5f'),
#   'address': {'building': '138',
#    'coord': [-73.98397539999999, 40.75796880000001],
#    'street': 'West 46 Street',
#    'zipcode': '10036'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 10, 30, 0, 0),
#     'grade': 'A',
#     'score': 7},
#    {'date': datetime.datetime(2014, 4, 14, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2013, 3, 22, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 8, 23, 0, 0), 'grade': 'C', 'score': 60},
#    {'date': datetime.datetime(2012, 3, 19, 0, 0), 'grade': 'A', 'score': 9}],
#   'name': 'Minar Indian Restaurant',
#   'restaurant_id': '40871006'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408dbd4'),
#   'address': {'building': '246',
#    'coord': [-73.96878889999999, 40.7554855],
#    'street': 'East   51 Street',
#    'zipcode': '10022'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 11, 12, 0, 0),
#     'grade': 'A',
#     'score': 8},
#    {'date': datetime.datetime(2014, 3, 25, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2013, 6, 24, 0, 0), 'grade': 'B', 'score': 18},
#    {'date': datetime.datetime(2013, 6, 11, 0, 0), 'grade': 'P', 'score': 5},
#    {'date': datetime.datetime(2012, 6, 19, 0, 0), 'grade': 'A', 'score': 10},
#    {'date': datetime.datetime(2011, 12, 14, 0, 0), 'grade': 'B', 'score': 18}],
#   'name': 'Amma',
#   'restaurant_id': '40885805'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408dc19'),
#   'address': {'building': '99',
#    'coord': [-74.0010291, 40.7296283],
#    'street': 'Mac Dougal Street',
#    'zipcode': '10012'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 6, 26, 0, 0),
#     'grade': 'B',
#     'score': 20},
#    {'date': datetime.datetime(2013, 4, 22, 0, 0), 'grade': 'A', 'score': 7},
#    {'date': datetime.datetime(2012, 4, 4, 0, 0), 'grade': 'A', 'score': 9}],
#   'name': 'The Kati Roll Company',
#   'restaurant_id': '40901527'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408dcbd'),
#   'address': {'building': '301',
#    'coord': [-73.973266, 40.678852],
#    'street': 'Flatbush Avenue',
#    'zipcode': '11217'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 9, 22, 0, 0),
#     'grade': 'A',
#     'score': 11},
#    {'date': datetime.datetime(2014, 4, 1, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2013, 7, 18, 0, 0), 'grade': 'A', 'score': 7},
#    {'date': datetime.datetime(2012, 9, 13, 0, 0), 'grade': 'B', 'score': 22},
#    {'date': datetime.datetime(2012, 4, 16, 0, 0), 'grade': 'C', 'score': 45},
#    {'date': datetime.datetime(2011, 9, 29, 0, 0), 'grade': 'B', 'score': 17}],
#   'name': 'Joy Indian Restaurant',
#   'restaurant_id': '40928416'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408dd0f'),
#   'address': {'building': '329',
#    'coord': [-73.982112, 40.73968600000001],
#    'street': '3 Avenue',
#    'zipcode': '10010'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 7, 1, 0, 0),
#     'grade': 'A',
#     'score': 12},
#    {'date': datetime.datetime(2013, 12, 31, 0, 0), 'grade': 'B', 'score': 25},
#    {'date': datetime.datetime(2013, 5, 15, 0, 0), 'grade': 'B', 'score': 22},
#    {'date': datetime.datetime(2012, 10, 15, 0, 0), 'grade': 'B', 'score': 14},
#    {'date': datetime.datetime(2012, 9, 12, 0, 0), 'grade': 'P', 'score': 3},
#    {'date': datetime.datetime(2011, 9, 1, 0, 0), 'grade': 'A', 'score': 11}],
#   'name': "Baluchi'S",
#   'restaurant_id': '40936006'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408dd6f'),
#   'address': {'building': '148',
#    'coord': [-73.973626, 40.7535539],
#    'street': 'East 46 Street',
#    'zipcode': '10017'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2015, 1, 8, 0, 0),
#     'grade': 'A',
#     'score': 10},
#    {'date': datetime.datetime(2014, 8, 21, 0, 0), 'grade': 'B', 'score': 16},
#    {'date': datetime.datetime(2014, 2, 10, 0, 0), 'grade': 'A', 'score': 8},
#    {'date': datetime.datetime(2013, 8, 9, 0, 0), 'grade': 'A', 'score': 2},
#    {'date': datetime.datetime(2012, 12, 24, 0, 0), 'grade': 'A', 'score': 5},
#    {'date': datetime.datetime(2012, 7, 17, 0, 0), 'grade': 'A', 'score': 11},
#    {'date': datetime.datetime(2012, 2, 10, 0, 0), 'grade': 'A', 'score': 13}],
#   'name': 'Joy Curry & Tandoor',
#   'restaurant_id': '40946298'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408dd7f'),
#   'address': {'building': '1',
#    'coord': [-73.8491683, 40.7599407],
#    'street': 'Worlds Fair Marina',
#    'zipcode': '11368'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 6, 20, 0, 0),
#     'grade': 'A',
#     'score': 10},
#    {'date': datetime.datetime(2013, 5, 24, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 12, 12, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 9, 24, 0, 0), 'grade': 'P', 'score': 9},
#    {'date': datetime.datetime(2012, 2, 27, 0, 0), 'grade': 'A', 'score': 2},
#    {'date': datetime.datetime(2011, 8, 18, 0, 0), 'grade': 'A', 'score': 11}],
#   'name': 'World Fair Marina Restaurant & Banquet',
#   'restaurant_id': '40947943'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408dd98'),
#   'address': {'building': '142',
#    'coord': [-73.99050510000001, 40.6870239],
#    'street': 'Smith Street',
#    'zipcode': '11201'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 12, 10, 0, 0),
#     'grade': 'A',
#     'score': 11},
#    {'date': datetime.datetime(2014, 3, 4, 0, 0), 'grade': 'A', 'score': 11},
#    {'date': datetime.datetime(2013, 9, 5, 0, 0), 'grade': 'B', 'score': 27},
#    {'date': datetime.datetime(2013, 6, 25, 0, 0), 'grade': 'P', 'score': 9},
#    {'date': datetime.datetime(2012, 7, 5, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2011, 12, 14, 0, 0), 'grade': 'B', 'score': 22}],
#   'name': 'Britain Indian Restaurant',
#   'restaurant_id': '40944839'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408de5e'),
#   'address': {'building': '275',
#    'coord': [-74.01099169999999, 40.7151804],
#    'street': 'Greenwich Street',
#    'zipcode': '10007'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 12, 16, 0, 0),
#     'grade': 'B',
#     'score': 14},
#    {'date': datetime.datetime(2014, 7, 18, 0, 0), 'grade': 'B', 'score': 18},
#    {'date': datetime.datetime(2014, 1, 8, 0, 0), 'grade': 'B', 'score': 26},
#    {'date': datetime.datetime(2013, 3, 27, 0, 0), 'grade': 'A', 'score': 2},
#    {'date': datetime.datetime(2012, 7, 3, 0, 0), 'grade': 'B', 'score': 19},
#    {'date': datetime.datetime(2012, 2, 8, 0, 0), 'grade': 'A', 'score': 10}],
#   'name': "Baluchi'S",
#   'restaurant_id': '40978503'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408df0a'),
#   'address': {'building': '2636',
#    'coord': [-73.9697065, 40.796989],
#    'street': 'Broadway',
#    'zipcode': '10025'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 8, 14, 0, 0),
#     'grade': 'A',
#     'score': 12},
#    {'date': datetime.datetime(2013, 8, 20, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 8, 27, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2012, 4, 16, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2011, 11, 29, 0, 0), 'grade': 'A', 'score': 13}],
#   'name': 'Indus Valley',
#   'restaurant_id': '40999144'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408df4e'),
#   'address': {'building': '97',
#    'coord': [-73.9829104, 40.7420053],
#    'street': 'Lexington Avenue',
#    'zipcode': '10016'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 1, 9, 0, 0),
#     'grade': 'A',
#     'score': 9},
#    {'date': datetime.datetime(2013, 1, 3, 0, 0), 'grade': 'A', 'score': 12}],
#   'name': 'Roomali',
#   'restaurant_id': '41004802'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408dfda'),
#   'address': {'building': '13408',
#    'coord': [-73.8032065, 40.674532],
#    'street': 'Rockaway Boulevard',
#    'zipcode': '11420'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 5, 12, 0, 0),
#     'grade': 'A',
#     'score': 10},
#    {'date': datetime.datetime(2013, 5, 9, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 5, 17, 0, 0), 'grade': 'A', 'score': 10},
#    {'date': datetime.datetime(2012, 1, 3, 0, 0), 'grade': 'A', 'score': 11},
#    {'date': datetime.datetime(2011, 6, 7, 0, 0), 'grade': 'B', 'score': 20}],
#   'name': 'Satguru Sweets & Catering',
#   'restaurant_id': '41016740'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408e04b'),
#   'address': {'building': '205',
#    'coord': [-73.9933012, 40.7482087],
#    'street': 'West 29 Street',
#    'zipcode': '10001'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 4, 22, 0, 0),
#     'grade': 'A',
#     'score': 12},
#    {'date': datetime.datetime(2013, 3, 18, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 3, 15, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2011, 9, 7, 0, 0), 'grade': 'B', 'score': 20},
#    {'date': datetime.datetime(2011, 4, 25, 0, 0), 'grade': 'C', 'score': 32}],
#   'name': 'Swagat Indian Restaurant',
#   'restaurant_id': '41028662'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408e0ea'),
#   'address': {'building': '152',
#    'coord': [-73.97352649999999, 40.753517],
#    'street': 'East   46 Street',
#    'zipcode': '10017'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 4, 24, 0, 0),
#     'grade': 'A',
#     'score': 7},
#    {'date': datetime.datetime(2013, 10, 29, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2013, 5, 1, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2012, 9, 10, 0, 0), 'grade': 'A', 'score': 4},
#    {'date': datetime.datetime(2012, 4, 17, 0, 0), 'grade': 'A', 'score': 7}],
#   'name': '1 Darbar',
#   'restaurant_id': '41046505'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408e148'),
#   'address': {'building': '473',
#    'coord': [-73.9869382, 40.6679967],
#    'street': '5 Avenue',
#    'zipcode': '11215'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 8, 27, 0, 0),
#     'grade': 'A',
#     'score': 9},
#    {'date': datetime.datetime(2014, 1, 6, 0, 0), 'grade': 'B', 'score': 20},
#    {'date': datetime.datetime(2013, 7, 18, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2013, 1, 30, 0, 0), 'grade': 'A', 'score': 2},
#    {'date': datetime.datetime(2012, 8, 9, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2011, 12, 29, 0, 0), 'grade': 'A', 'score': 10}],
#   'name': 'Kinara Indian Restaurant',
#   'restaurant_id': '41060552'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408e1e2'),
#   'address': {'building': '992',
#    'coord': [-73.9644394, 40.8025791],
#    'street': 'Amsterdam Avenue',
#    'zipcode': '10025'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 11, 12, 0, 0),
#     'grade': 'Z',
#     'score': 20},
#    {'date': datetime.datetime(2014, 5, 14, 0, 0), 'grade': 'C', 'score': 43},
#    {'date': datetime.datetime(2013, 6, 25, 0, 0), 'grade': 'A', 'score': 4},
#    {'date': datetime.datetime(2012, 5, 24, 0, 0), 'grade': 'A', 'score': 9}],
#   'name': 'Roti Roll / Suite',
#   'restaurant_id': '41077631'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408e2c4'),
#   'address': {'building': '7220',
#    'coord': [-73.87991339999999, 40.7480773],
#    'street': 'Roosevelt Avenue',
#    'zipcode': '11372'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 4, 30, 0, 0),
#     'grade': 'A',
#     'score': 13},
#    {'date': datetime.datetime(2013, 10, 22, 0, 0), 'grade': 'C', 'score': 47},
#    {'date': datetime.datetime(2013, 4, 8, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2012, 2, 6, 0, 0), 'grade': 'A', 'score': 11}],
#   'name': 'Himalayan Yak Restaurant',
#   'restaurant_id': '41100434'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408e2fa'),
#   'address': {'building': '564',
#    'coord': [-73.9746849, 40.78868500000001],
#    'street': 'Amsterdam Avenue',
#    'zipcode': '10024'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 12, 1, 0, 0),
#     'grade': 'A',
#     'score': 8},
#    {'date': datetime.datetime(2013, 12, 3, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2012, 12, 6, 0, 0), 'grade': 'A', 'score': 3},
#    {'date': datetime.datetime(2011, 12, 8, 0, 0), 'grade': 'A', 'score': 9}],
#   'name': 'Indian Tanpura',
#   'restaurant_id': '41105180'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408e305'),
#   'address': {'building': '3926',
#    'coord': [-73.9032005, 40.7465439],
#    'street': '61 Street',
#    'zipcode': '11377'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 12, 22, 0, 0),
#     'grade': 'A',
#     'score': 12},
#    {'date': datetime.datetime(2013, 12, 20, 0, 0), 'grade': 'A', 'score': 3},
#    {'date': datetime.datetime(2013, 6, 12, 0, 0), 'grade': 'A', 'score': 11},
#    {'date': datetime.datetime(2012, 5, 8, 0, 0), 'grade': 'A', 'score': 13}],
#   'name': 'Masala',
#   'restaurant_id': '41106252'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408e382'),
#   'address': {'building': '118-08',
#    'coord': [-73.8284668, 40.693852],
#    'street': 'Atlantic Avenue',
#    'zipcode': '11419'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 10, 9, 0, 0),
#     'grade': 'A',
#     'score': 12},
#    {'date': datetime.datetime(2014, 3, 31, 0, 0), 'grade': 'A', 'score': 7},
#    {'date': datetime.datetime(2013, 8, 12, 0, 0), 'grade': 'B', 'score': 17},
#    {'date': datetime.datetime(2013, 1, 30, 0, 0), 'grade': 'A', 'score': 11},
#    {'date': datetime.datetime(2012, 8, 8, 0, 0), 'grade': 'A', 'score': 11},
#    {'date': datetime.datetime(2012, 2, 7, 0, 0), 'grade': 'C', 'score': 44}],
#   'name': 'Royal India Palace And Restaurant',
#   'restaurant_id': '41119269'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408e3d7'),
#   'address': {'building': '126',
#    'coord': [-73.9830659, 40.742643],
#    'street': 'East   28 Street',
#    'zipcode': '10016'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 7, 3, 0, 0),
#     'grade': 'A',
#     'score': 9},
#    {'date': datetime.datetime(2013, 5, 30, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2012, 10, 3, 0, 0), 'grade': 'B', 'score': 25}],
#   'name': 'Copper Chimney',
#   'restaurant_id': '41131042'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408e3e4'),
#   'address': {'building': '150',
#    'coord': [-73.97147850000002, 40.7558797],
#    'street': 'East   50 Street',
#    'zipcode': '10022'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 2, 8, 0, 0),
#     'grade': 'A',
#     'score': 10},
#    {'date': datetime.datetime(2012, 12, 13, 0, 0), 'grade': 'A', 'score': 10},
#    {'date': datetime.datetime(2012, 6, 4, 0, 0), 'grade': 'A', 'score': 3},
#    {'date': datetime.datetime(2011, 12, 21, 0, 0), 'grade': 'A', 'score': 7},
#    {'date': datetime.datetime(2011, 4, 28, 0, 0), 'grade': 'A', 'score': 12}],
#   'name': 'Mint',
#   'restaurant_id': '41132845'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408e3e6'),
#   'address': {'building': '66',
#    'coord': [-73.9851764, 40.7526057],
#    'street': 'West   39 Street',
#    'zipcode': '10018'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 10, 20, 0, 0),
#     'grade': 'B',
#     'score': 24},
#    {'date': datetime.datetime(2014, 5, 5, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2013, 10, 18, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2013, 2, 7, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2012, 6, 6, 0, 0), 'grade': 'A', 'score': 11},
#    {'date': datetime.datetime(2011, 11, 16, 0, 0), 'grade': 'A', 'score': 13}],
#   'name': 'Curry Dream',
#   'restaurant_id': '41132647'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408e41b'),
#   'address': {'building': '148-01',
#    'coord': [-73.808793, 40.7062839],
#    'street': 'Hillside Avenue',
#    'zipcode': '11435'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 9, 29, 0, 0),
#     'grade': 'A',
#     'score': 13},
#    {'date': datetime.datetime(2014, 4, 28, 0, 0), 'grade': 'A', 'score': 10},
#    {'date': datetime.datetime(2013, 10, 16, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2013, 4, 11, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2012, 10, 2, 0, 0), 'grade': 'A', 'score': 7},
#    {'date': datetime.datetime(2012, 4, 9, 0, 0), 'grade': 'B', 'score': 19},
#    {'date': datetime.datetime(2012, 4, 2, 0, 0), 'grade': 'P', 'score': 2},
#    {'date': datetime.datetime(2011, 12, 6, 0, 0), 'grade': 'B', 'score': 16}],
#   'name': 'Taj Mahal Restaurant',
#   'restaurant_id': '41139460'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408e459'),
#   'address': {'building': '322',
#    'coord': [-74.0852984, 40.6342088],
#    'street': 'Victory Boulevard',
#    'zipcode': '10301'},
#   'borough': 'Staten Island',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 3, 4, 0, 0),
#     'grade': 'A',
#     'score': 10},
#    {'date': datetime.datetime(2013, 2, 28, 0, 0), 'grade': 'A', 'score': 11},
#    {'date': datetime.datetime(2012, 2, 14, 0, 0), 'grade': 'A', 'score': 12}],
#   'name': 'New Asha Sri Lankan Restaurant',
#   'restaurant_id': '41145557'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408e471'),
#   'address': {'building': '230',
#    'coord': [-73.965885, 40.760184],
#    'street': 'East   58 Street',
#    'zipcode': '10022'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 7, 16, 0, 0),
#     'grade': 'A',
#     'score': 12},
#    {'date': datetime.datetime(2013, 6, 18, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2013, 1, 2, 0, 0), 'grade': 'B', 'score': 14},
#    {'date': datetime.datetime(2012, 2, 21, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2011, 10, 5, 0, 0), 'grade': 'A', 'score': 11}],
#   'name': 'Yuva Frontier Indian Grill',
#   'restaurant_id': '41148105'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408e4c1'),
#   'address': {'building': '464',
#    'coord': [-73.9769331, 40.7854107],
#    'street': 'Amsterdam Avenue',
#    'zipcode': '10024'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 10, 31, 0, 0),
#     'grade': 'A',
#     'score': 5},
#    {'date': datetime.datetime(2014, 5, 8, 0, 0), 'grade': 'A', 'score': 4},
#    {'date': datetime.datetime(2013, 10, 25, 0, 0), 'grade': 'A', 'score': 10},
#    {'date': datetime.datetime(2012, 9, 10, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2012, 4, 27, 0, 0), 'grade': 'A', 'score': 7},
#    {'date': datetime.datetime(2011, 11, 17, 0, 0), 'grade': 'A', 'score': 13}],
#   'name': 'Hampton Chutney, Co.',
#   'restaurant_id': '41155027'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408e5da'),
#   'address': {'building': '239',
#    'coord': [-73.98267779999999, 40.7316471],
#    'street': '1 Avenue',
#    'zipcode': '10003'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 12, 9, 0, 0),
#     'grade': 'A',
#     'score': 9},
#    {'date': datetime.datetime(2014, 8, 5, 0, 0), 'grade': 'C', 'score': 32},
#    {'date': datetime.datetime(2013, 12, 4, 0, 0), 'grade': 'A', 'score': 9},
# ...
#     'score': 23},
#    {'date': datetime.datetime(2014, 5, 12, 0, 0), 'grade': 'B', 'score': 27}],
#   'name': 'Spicy Lanka',
#   'restaurant_id': '50006427'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092154'),
#   'address': {'building': '135',
#    'coord': [-73.9821545, 40.74252509999999],
#    'street': 'E 28Th St',
#    'zipcode': '10016'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 10, 3, 0, 0),
#     'grade': 'A',
#     'score': 9},
#    {'date': datetime.datetime(2014, 3, 31, 0, 0), 'grade': 'A', 'score': 9}],
#   'name': 'Patal Asia Deli Grocery',
#   'restaurant_id': '50006552'},
#  {'_id': ObjectId('626675ed1b3fa6fbc409219b'),
#   'address': {'building': '1043',
#    'coord': [-73.966376, 40.632288],
#    'street': 'Coney Island Avenue',
#    'zipcode': '11230'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 6, 16, 0, 0),
#     'grade': 'A',
#     'score': 12}],
#   'name': 'Gyro Hut',
#   'restaurant_id': '50006965'},
#  {'_id': ObjectId('626675ed1b3fa6fbc40921be'),
#   'address': {'building': '91-81',
#    'coord': [-73.8347252, 40.6924016],
#    'street': '111 Street',
#    'zipcode': '11418'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 6, 18, 0, 0),
#     'grade': 'A',
#     'score': 8}],
#   'name': 'Moon Light  Crill Rest.',
#   'restaurant_id': '50007097'},
#  {'_id': ObjectId('626675ed1b3fa6fbc40921d3'),
#   'address': {'building': '257',
#    'coord': [-73.9927663, 40.6831133],
#    'street': 'Smith Street',
#    'zipcode': '11231'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 3, 31, 0, 0),
#     'grade': 'A',
#     'score': 9}],
#   'name': 'Bombay Dream',
#   'restaurant_id': '50007196'},
#  {'_id': ObjectId('626675ed1b3fa6fbc409222a'),
#   'address': {'building': '100',
#    'coord': [-73.98308999999999, 40.74222],
#    'street': 'Lexington Avenue',
#    'zipcode': '10016'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 5, 30, 0, 0),
#     'grade': 'A',
#     'score': 10}],
#   'name': 'Bhatti Indian Grill',
#   'restaurant_id': '50007475'},
#  {'_id': ObjectId('626675ed1b3fa6fbc409225f'),
#   'address': {'building': '931',
#    'coord': [-73.96558499999999, 40.800037],
#    'street': 'Amsterdam Avenue',
#    'zipcode': '10025'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 5, 12, 0, 0),
#     'grade': 'A',
#     'score': 9}],
#   'name': 'Maharaja Palace',
#   'restaurant_id': '50007798'},
#  {'_id': ObjectId('626675ed1b3fa6fbc409229c'),
#   'address': {'building': '764A',
#    'coord': [-73.9880435, 40.7641423],
#    'street': '9 Avenue',
#    'zipcode': '10019'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 3, 14, 0, 0),
#     'grade': 'A',
#     'score': 9}],
#   'name': 'Bombay Grill House',
#   'restaurant_id': '50008021'},
#  {'_id': ObjectId('626675ed1b3fa6fbc409230e'),
#   'address': {'building': '101',
#    'coord': [-73.982524, 40.742068],
#    'street': 'Lexington Avenue',
#    'zipcode': '10016'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 4, 21, 0, 0),
#     'grade': 'A',
#     'score': 9}],
#   'name': 'Desi Galli',
#   'restaurant_id': '50008310'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092334'),
#   'address': {'building': '489',
#    'coord': [-73.97300899999999, 40.784756],
#    'street': 'Columbus Avenue',
#    'zipcode': '10024'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 5, 29, 0, 0),
#     'grade': 'A',
#     'score': 12}],
#   'name': 'Savoury Indian Cuisine',
#   'restaurant_id': '50008448'},
#  {'_id': ObjectId('626675ed1b3fa6fbc40923bd'),
#   'address': {'building': '99',
#    'coord': [-73.9826923, 40.7420798],
#    'street': 'Lexington Avenue',
#    'zipcode': '10016'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 7, 22, 0, 0),
#     'grade': 'B',
#     'score': 16}],
#   'name': 'Kailash Parbat',
#   'restaurant_id': '50008960'},
#  {'_id': ObjectId('626675ed1b3fa6fbc40924b0'),
#   'address': {'building': '48',
#    'coord': [-73.98032719999999, 40.7579779],
#    'street': 'West   48 Street',
#    'zipcode': '10036'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 8, 7, 0, 0),
#     'grade': 'A',
#     'score': 9}],
#   'name': 'Spice Grill',
#   'restaurant_id': '50009888'},
#  {'_id': ObjectId('626675ed1b3fa6fbc40924f3'),
#   'address': {'building': '1241',
#    'coord': [-73.954853, 40.640097],
#    'street': 'Flatbush Avenue',
#    'zipcode': '11226'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 6, 10, 0, 0),
#     'grade': 'A',
#     'score': 13}],
#   'name': 'Curry Spot',
#   'restaurant_id': '50010077'},
#  {'_id': ObjectId('626675ed1b3fa6fbc40925c0'),
#   'address': {'building': '42-02',
#    'coord': [-73.77073299999999, 40.762456],
#    'street': 'Bell Boulevard',
#    'zipcode': '11361'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2015, 1, 2, 0, 0),
#     'grade': 'A',
#     'score': 10}],
#   'name': 'Masala Box',
#   'restaurant_id': '50010873'},
#  {'_id': ObjectId('626675ed1b3fa6fbc40925f2'),
#   'address': {'building': '2588',
#    'coord': [-73.9707432, 40.7955865],
#    'street': 'Broadway',
#    'zipcode': '10025'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 11, 26, 0, 0),
#     'grade': 'B',
#     'score': 25}],
#   'name': 'Awadh',
#   'restaurant_id': '50011024'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092610'),
#   'address': {'building': '1436',
#    'coord': [-73.9510279, 40.635562],
#    'street': 'Flatbush Avenue',
#    'zipcode': '11210'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 8, 12, 0, 0),
#     'grade': 'A',
#     'score': 9}],
#   'name': 'Ashoka Grill',
#   'restaurant_id': '50011121'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092613'),
#   'address': {'building': '95',
#    'coord': [-74.00113999999999, 40.729529],
#    'street': 'Macdougal Street',
#    'zipcode': '10012'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 10, 21, 0, 0),
#     'grade': 'B',
#     'score': 21}],
#   'name': 'Mirch Masala',
#   'restaurant_id': '50011127'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092617'),
#   'address': {'building': '324',
#    'coord': [-73.98743309999999, 40.7267339],
#    'street': 'East    6 Street',
#    'zipcode': '10003'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 7, 14, 0, 0),
#     'grade': 'A',
#     'score': 9}],
#   'name': 'Jewel Of India',
#   'restaurant_id': '50011136'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092620'),
#   'address': {'building': '119-08',
#    'coord': [-73.82737279999999, 40.6936343],
#    'street': '94 Avenue',
#    'zipcode': '11419'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 8, 15, 0, 0),
#     'grade': 'A',
#     'score': 11}],
#   'name': 'New Tandoori Hut',
#   'restaurant_id': '50011142'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092644'),
#   'address': {'building': '31-31',
#    'coord': [-73.93416140000001, 40.7449824],
#    'street': 'Thomson Avenue',
#    'zipcode': '11101'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 9, 25, 0, 0),
#     'grade': 'A',
#     'score': 7}],
#   'name': 'Spicy Mela',
#   'restaurant_id': '50011296'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092652'),
#   'address': {'building': '109-08',
#    'coord': [-73.83252999999999, 40.683892],
#    'street': 'Liberty Avenue',
#    'zipcode': '11419'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2015, 1, 20, 0, 0),
#     'grade': 'Not Yet Graded',
#     'score': 38}],
#   'name': 'Aladdin Hookah Lounge & Bar Inc',
#   'restaurant_id': '50011338'},
#  {'_id': ObjectId('626675ed1b3fa6fbc40926d4'),
#   'address': {'building': '70-74',
#    'coord': [-73.8151755, 40.7299107],
#    'street': 'Kissena Boulevard',
#    'zipcode': '11367'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 11, 7, 0, 0),
#     'grade': 'A',
#     'score': 9}],
#   'name': 'Indochi Fusion Cuisine',
#   'restaurant_id': '50011749'},
#  {'_id': ObjectId('626675ed1b3fa6fbc40926f8'),
#   'address': {'building': '99',
#    'coord': [-73.988978, 40.727377],
#    'street': '2 Avenue',
#    'zipcode': '10003'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 9, 15, 0, 0),
#     'grade': 'A',
#     'score': 3}],
#   'name': 'Bricklane Curry House',
#   'restaurant_id': '50011919'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092772'),
#   'address': {'building': '135-08',
#    'coord': [-73.8115541, 40.6916918],
#    'street': 'Liberty Avenue',
#    'zipcode': '11419'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 8, 13, 0, 0),
#     'grade': 'A',
#     'score': 12}],
#   'name': 'Indian Diner',
#   'restaurant_id': '50012295'},
#  {'_id': ObjectId('626675ed1b3fa6fbc40927e0'),
#   'address': {'building': '216',
#    'coord': [-73.98534699999999, 40.736252],
#    'street': '3 Avenue',
#    'zipcode': '10003'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 10, 14, 0, 0),
#     'grade': 'A',
#     'score': 10}],
#   'name': 'A Spice Lane',
#   'restaurant_id': '50012690'},
#  {'_id': ObjectId('626675ed1b3fa6fbc40927e9'),
#   'address': {'building': '1961',
#    'coord': [-73.935937, 40.622162],
#    'street': 'Flatbush Avenue',
#    'zipcode': '11234'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 8, 13, 0, 0),
#     'grade': 'A',
#     'score': 12}],
#   'name': 'Agra King Restaurant',
#   'restaurant_id': '50012743'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092874'),
#   'address': {'building': '6',
#    'coord': [-73.98380399999999, 40.72102599999999],
#    'street': 'Clinton Street',
#    'zipcode': '10002'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 10, 9, 0, 0),
#     'grade': 'A',
#     'score': 9}],
#   'name': 'Khushboo Indian Restaurant',
#   'restaurant_id': '50013373'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092918'),
#   'address': {'building': '180-10',
#    'coord': [-73.7876884, 40.7269966],
#    'street': 'Union Turnpike',
#    'zipcode': '11366'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 12, 11, 0, 0),
#     'grade': 'A',
#     'score': 6}],
#   'name': "Dhruv'S Kati Shack Factory",
#   'restaurant_id': '50014020'},
#  {'_id': ObjectId('626675ed1b3fa6fbc409293a'),
#   'address': {'building': '243-08',
#    'coord': [-73.7261903, 40.7408608],
#    'street': 'Union Turnpike',
#    'zipcode': '11426'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 12, 1, 0, 0),
#     'grade': 'Z',
#     'score': 26}],
#   'name': 'Sohna Punjab Indian Restaurant',
#   'restaurant_id': '50014166'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092959'),
#   'address': {'building': '980',
#    'coord': [-73.916853, 40.8284184],
#    'street': 'Morris Avenue',
#    'zipcode': '10456'},
#   'borough': 'Bronx',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 9, 30, 0, 0),
#     'grade': 'A',
#     'score': 11}],
#   'name': 'Hungry Bird',
#   'restaurant_id': '50014239'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092a60'),
#   'address': {'building': '37',
#    'coord': [-73.9821244, 40.7551156],
#    'street': 'West   43 Street',
#    'zipcode': '10036'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 10, 27, 0, 0),
#     'grade': 'A',
#     'score': 7}],
#   'name': "Baluchi'S Fresh",
#   'restaurant_id': '50015083'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092a7f'),
#   'address': {'building': '54',
#    'coord': [-73.97458200000001, 40.6760504],
#    'street': '7 Avenue',
#    'zipcode': '11217'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 10, 22, 0, 0),
#     'grade': 'A',
#     'score': 7}],
#   'name': 'Tikka Grill',
#   'restaurant_id': '50015168'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092b03'),
#   'address': {'building': '63-108',
#    'coord': [-73.8671967, 40.7216631],
#    'street': 'Woodhaven Boulevard',
#    'zipcode': '11374'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 11, 18, 0, 0),
#     'grade': 'Z',
#     'score': 27}],
#   'name': 'Mayurya Banquet Hall & Restaurant',
#   'restaurant_id': '50015517'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092b10'),
#   'address': {'building': '1393A',
#    'coord': [-73.9582662, 40.7692944],
#    'street': '2Nd Ave',
#    'zipcode': '10021'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 12, 17, 0, 0),
#     'grade': 'A',
#     'score': 9}],
#   'name': 'Rongoli Exquiste Indian Cuisine',
#   'restaurant_id': '50015570'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092b2e'),
#   'address': {'building': '501B',
#    'coord': [-73.9811696, 40.6856789],
#    'street': 'Atlantic Ave',
#    'zipcode': '11217'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 11, 20, 0, 0),
#     'grade': 'A',
#     'score': 8}],
#   'name': 'Masala Grill',
#   'restaurant_id': '50015676'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092b3b'),
#   'address': {'building': '185',
#    'coord': [-73.94694419999999, 40.727182],
#    'street': 'Norman Avenue',
#    'zipcode': '11222'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 12, 2, 0, 0),
#     'grade': 'A',
#     'score': 12}],
#   'name': 'Moha Rani',
#   'restaurant_id': '50015744'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092c8f'),
#   'address': {'building': '787',
#    'coord': [-73.9504151, 40.6743447],
#    'street': 'Prospect Place',
#    'zipcode': '11216'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 11, 13, 0, 0),
#     'grade': 'A',
#     'score': 9}],
#   'name': 'Curry Garden',
#   'restaurant_id': '50016742'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092d4f'),
#   'address': {'building': '116-33',
#    'coord': [-73.8481583, 40.723557],
#    'street': 'Queens Boulevard',
#    'zipcode': '11375'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2015, 1, 20, 0, 0),
#     'grade': 'Not Yet Graded',
#     'score': 30}],
#   'name': 'Haveli Fine Indian Cuisine',
#   'restaurant_id': '50017167'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092d7d'),
#   'address': {'building': '443',
#    'coord': [-73.936898, 40.70231],
#    'street': 'Bushwick Ave',
#    'zipcode': '11206'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2015, 1, 7, 0, 0),
#     'grade': 'A',
#     'score': 13}],
#   'name': 'All About Indian Food',
#   'restaurant_id': '50017266'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092e51'),
#   'address': {'building': '318',
#    'coord': [-73.9876705, 40.7268324],
#    'street': 'East 6 Street',
#    'zipcode': '10003'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2015, 1, 20, 0, 0),
#     'grade': 'Not Yet Graded',
#     'score': 25}],
#   'name': 'Malai Marke',
#   'restaurant_id': '50017819'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092ecb'),
#   'address': {'building': '396',
#    'coord': [-73.985271, 40.6707256],
#    'street': '5Th Ave',
#    'zipcode': '11215'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2015, 1, 20, 0, 0),
#     'grade': 'Not Yet Graded',
#     'score': 26}],
#   'name': 'New Aarpan',
#   'restaurant_id': '50018087'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092f9b'),
#   'address': {'building': '351',
#    'coord': [-73.9819936, 40.6660587],
#    'street': '7Th Ave',
#    'zipcode': '11215'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2015, 1, 20, 0, 0),
#     'grade': 'Not Yet Graded',
#     'score': 9}],
#   'name': 'Indian Spice',
#   'restaurant_id': '50018514'}]

# %% [markdown]
# ### Query all Indian and Thai cuisines

# %%
list(collection.find({'cuisine': {'$in': ['Indian', 'Thai']}}))
# Out:
# [{'_id': ObjectId('626675eb1b3fa6fbc408ce8b'),
#   'address': {'building': '320',
#    'coord': [-73.977597, 40.779593],
#    'street': 'Columbus Avenue',
#    'zipcode': '10023'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 10, 27, 0, 0),
#     'grade': 'A',
#     'score': 7},
#    {'date': datetime.datetime(2013, 7, 29, 0, 0), 'grade': 'A', 'score': 5},
#    {'date': datetime.datetime(2013, 2, 19, 0, 0), 'grade': 'A', 'score': 11},
#    {'date': datetime.datetime(2012, 1, 12, 0, 0), 'grade': 'A', 'score': 2}],
#   'name': 'Mughlai Restaurant',
#   'restaurant_id': '40370243'},
#  {'_id': ObjectId('626675eb1b3fa6fbc408cedf'),
#   'address': {'building': '244',
#    'coord': [-73.9865289, 40.7606981],
#    'street': 'West   48 Street',
#    'zipcode': '10036'},
#   'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2014, 8, 13, 0, 0),
#     'grade': 'A',
#     'score': 10},
#    {'date': datetime.datetime(2014, 1, 14, 0, 0), 'grade': 'B', 'score': 24},
#    {'date': datetime.datetime(2013, 7, 25, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2013, 1, 10, 0, 0), 'grade': 'C', 'score': 4},
#    {'date': datetime.datetime(2012, 6, 18, 0, 0), 'grade': 'A', 'score': 11},
#    {'date': datetime.datetime(2012, 2, 17, 0, 0), 'grade': 'P', 'score': 6}],
#   'name': 'Pongsri Thai Restaurant',
#   'restaurant_id': '40374088'},
#  {'_id': ObjectId('626675eb1b3fa6fbc408cef2'),
#   'address': {'building': '807',
#    'coord': [-73.96643449999999, 40.7641697],
#    'street': 'Lexington Avenue',
#    'zipcode': '10065'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 10, 28, 0, 0),
#     'grade': 'A',
#     'score': 10},
#    {'date': datetime.datetime(2014, 7, 9, 0, 0), 'grade': 'B', 'score': 24},
#    {'date': datetime.datetime(2014, 1, 17, 0, 0), 'grade': 'A', 'score': 11},
#    {'date': datetime.datetime(2013, 5, 28, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2012, 3, 27, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2011, 11, 2, 0, 0), 'grade': 'C', 'score': 28}],
#   'name': 'Agra Restaurant',
#   'restaurant_id': '40375376'},
#  {'_id': ObjectId('626675eb1b3fa6fbc408cf4d'),
#   'address': {'building': '8443',
#    'coord': [-73.80112059999999, 40.7128278],
#    'street': '164 Street',
#    'zipcode': '11432'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 11, 28, 0, 0),
#     'grade': 'A',
#     'score': 4},
#    {'date': datetime.datetime(2014, 6, 16, 0, 0), 'grade': 'A', 'score': 8},
#    {'date': datetime.datetime(2013, 5, 15, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 5, 29, 0, 0), 'grade': 'A', 'score': 13}],
#   'name': 'Annam Braham Restaurant',
#   'restaurant_id': '40380520'},
#  {'_id': ObjectId('626675eb1b3fa6fbc408cf5a'),
#   'address': {'building': '345',
#    'coord': [-73.9864626, 40.7266739],
#    'street': 'East 6 Street',
#    'zipcode': '10003'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 9, 15, 0, 0),
#     'grade': 'A',
#     'score': 5},
#    {'date': datetime.datetime(2014, 1, 14, 0, 0), 'grade': 'A', 'score': 8},
#    {'date': datetime.datetime(2013, 5, 30, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2013, 4, 24, 0, 0), 'grade': 'P', 'score': 2},
#    {'date': datetime.datetime(2012, 10, 1, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2012, 4, 6, 0, 0), 'grade': 'C', 'score': 92},
#    {'date': datetime.datetime(2011, 11, 3, 0, 0), 'grade': 'C', 'score': 41}],
#   'name': 'Gandhi',
#   'restaurant_id': '40381295'},
#  {'_id': ObjectId('626675eb1b3fa6fbc408cf95'),
#   'address': {'building': '7407',
#    'coord': [-74.0272951, 40.6318285],
#    'street': '3 Avenue',
#    'zipcode': '11209'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 12, 17, 0, 0),
#     'grade': 'Z',
#     'score': 15},
#    {'date': datetime.datetime(2014, 6, 19, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2013, 10, 2, 0, 0), 'grade': 'B', 'score': 16},
#    {'date': datetime.datetime(2013, 4, 15, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2012, 7, 23, 0, 0), 'grade': 'A', 'score': 6},
#    {'date': datetime.datetime(2011, 12, 20, 0, 0), 'grade': 'A', 'score': 12}],
#   'name': 'India Passage Restaurant',
#   'restaurant_id': '40384479'},
#  {'_id': ObjectId('626675eb1b3fa6fbc408d04a'),
#   'address': {'building': '100',
#    'coord': [-73.988342, 40.727111],
#    'street': 'Second Avenue',
#    'zipcode': '10003'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 11, 24, 0, 0),
#     'grade': 'A',
#     'score': 12},
#    {'date': datetime.datetime(2014, 4, 21, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2013, 3, 1, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2012, 2, 15, 0, 0), 'grade': 'A', 'score': 12}],
#   'name': 'Haveli',
#   'restaurant_id': '40390209'},
#  {'_id': ObjectId('626675eb1b3fa6fbc408d055'),
#   'address': {'building': '287',
#    'coord': [-74.1126424, 40.5722235],
#    'street': 'Newdorp Ln',
#    'zipcode': '10306'},
#   'borough': 'Staten Island',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 6, 20, 0, 0),
#     'grade': 'A',
#     'score': 4},
#    {'date': datetime.datetime(2013, 5, 21, 0, 0), 'grade': 'A', 'score': 10},
#    {'date': datetime.datetime(2012, 5, 8, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2011, 12, 22, 0, 0), 'grade': 'A', 'score': 12}],
#   'name': 'Taste Of India Ii Restaurant',
#   'restaurant_id': '40390536'},
#  {'_id': ObjectId('626675eb1b3fa6fbc408d0a0'),
#   'address': {'building': '396',
#    'coord': [-73.9809909, 40.7422324],
#    'street': 'Third Avenue',
#    'zipcode': '10016'},
#   'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2014, 10, 30, 0, 0),
#     'grade': 'A',
#     'score': 13},
#    {'date': datetime.datetime(2014, 6, 4, 0, 0), 'grade': 'A', 'score': 7},
#    {'date': datetime.datetime(2013, 3, 8, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2012, 10, 1, 0, 0), 'grade': 'A', 'score': 9}],
#   'name': 'Jaiya Thai Oriental Restaurant',
#   'restaurant_id': '40392724'},
#  {'_id': ObjectId('626675eb1b3fa6fbc408d0e5'),
#   'address': {'building': '127',
#    'coord': [-73.978911, 40.764421],
#    'street': 'West   56 Street',
#    'zipcode': '10019'},
#   'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2014, 3, 20, 0, 0),
#     'grade': 'A',
#     'score': 7},
#    {'date': datetime.datetime(2013, 6, 19, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2012, 12, 13, 0, 0), 'grade': 'B', 'score': 22},
#    {'date': datetime.datetime(2012, 5, 14, 0, 0), 'grade': 'A', 'score': 13}],
#   'name': 'Topaz Thai Restaurant',
#   'restaurant_id': '40394164'},
#  {'_id': ObjectId('626675eb1b3fa6fbc408d0ef'),
#   'address': {'building': '148',
#    'coord': [-73.983139, 40.759967],
#    'street': 'West   49 Street',
#    'zipcode': '10019'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 9, 22, 0, 0),
#     'grade': 'A',
#     'score': 9},
#    {'date': datetime.datetime(2014, 5, 12, 0, 0), 'grade': 'A', 'score': 10},
#    {'date': datetime.datetime(2013, 11, 4, 0, 0), 'grade': 'A', 'score': 5},
#    {'date': datetime.datetime(2013, 2, 25, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2012, 7, 5, 0, 0), 'grade': 'A', 'score': 11},
#    {'date': datetime.datetime(2011, 11, 25, 0, 0), 'grade': 'B', 'score': 15}],
#   'name': 'Bombay Masala',
#   'restaurant_id': '40394066'},
#  {'_id': ObjectId('626675eb1b3fa6fbc408d12d'),
#   'address': {'building': '357',
#    'coord': [-73.96642899999999, 40.754211],
#    'street': 'East 50 Street',
#    'zipcode': '10022'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 4, 24, 0, 0),
#     'grade': 'A',
#     'score': 11},
#    {'date': datetime.datetime(2013, 10, 22, 0, 0), 'grade': 'A', 'score': 6},
#    {'date': datetime.datetime(2013, 4, 3, 0, 0), 'grade': 'A', 'score': 11},
#    {'date': datetime.datetime(2012, 7, 23, 0, 0), 'grade': 'B', 'score': 21},
#    {'date': datetime.datetime(2011, 10, 13, 0, 0), 'grade': 'B', 'score': 15}],
#   'name': 'Indigo Indian Cuisine',
#   'restaurant_id': '40395748'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d14a'),
#   'address': {'building': '3205',
#    'coord': [-73.9243079, 40.7565289],
#    'street': '36 Avenue',
#    'zipcode': '11106'},
#   'borough': 'Queens',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2014, 10, 20, 0, 0),
#     'grade': 'B',
#     'score': 25},
#    {'date': datetime.datetime(2014, 5, 7, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2013, 11, 9, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2013, 5, 7, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2012, 10, 5, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 4, 12, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2012, 3, 28, 0, 0), 'grade': 'P', 'score': 9}],
#   'name': 'Arharn Thai Cuisine',
#   'restaurant_id': '40396267'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d1a2'),
#   'address': {'building': '119',
#    'coord': [-73.982139, 40.742638],
#    'street': 'Lexington Avenue',
#    'zipcode': '10016'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 10, 15, 0, 0),
#     'grade': 'A',
#     'score': 12},
#    {'date': datetime.datetime(2014, 4, 14, 0, 0), 'grade': 'B', 'score': 15},
#    {'date': datetime.datetime(2013, 10, 23, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2013, 4, 8, 0, 0), 'grade': 'B', 'score': 19},
#    {'date': datetime.datetime(2012, 10, 19, 0, 0), 'grade': 'B', 'score': 26},
#    {'date': datetime.datetime(2012, 5, 23, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2011, 12, 30, 0, 0), 'grade': 'C', 'score': 37}],
#   'name': 'Curry In A Hurry',
#   'restaurant_id': '40398434'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d1cd'),
#   'address': {'building': '882',
#    'coord': [-73.966044, 40.7536346],
#    'street': 'First Avenue',
#    'zipcode': '10022'},
#   'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2014, 11, 24, 0, 0),
#     'grade': 'A',
#     'score': 12},
#    {'date': datetime.datetime(2014, 6, 19, 0, 0), 'grade': 'A', 'score': 5},
#    {'date': datetime.datetime(2013, 5, 1, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 4, 26, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2011, 12, 21, 0, 0), 'grade': 'B', 'score': 24}],
#   'name': 'Bangkok Grand Palace',
#   'restaurant_id': '40399285'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d208'),
#   'address': {'building': '6735',
#    'coord': [-74.025231, 40.636865],
#    'street': '3 Avenue',
#    'zipcode': '11220'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2014, 5, 29, 0, 0),
#     'grade': 'A',
#     'score': 4},
#    {'date': datetime.datetime(2013, 6, 4, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 6, 28, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2011, 12, 17, 0, 0), 'grade': 'A', 'score': 5},
#    {'date': datetime.datetime(2011, 8, 16, 0, 0), 'grade': 'A', 'score': 10}],
#   'name': 'Bangkok Thai House',
#   'restaurant_id': '40400324'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d234'),
#   'address': {'building': '27',
#    'coord': [-73.9890071, 40.7391277],
#    'street': 'East 20 Street',
#    'zipcode': '10003'},
#   'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2014, 11, 18, 0, 0),
#     'grade': 'A',
#     'score': 6},
#    {'date': datetime.datetime(2014, 5, 20, 0, 0), 'grade': 'A', 'score': 10},
#    {'date': datetime.datetime(2013, 11, 22, 0, 0), 'grade': 'A', 'score': 5},
#    {'date': datetime.datetime(2013, 5, 15, 0, 0), 'grade': 'A', 'score': 10},
#    {'date': datetime.datetime(2012, 8, 6, 0, 0), 'grade': 'C', 'score': 68},
#    {'date': datetime.datetime(2012, 4, 13, 0, 0), 'grade': 'C', 'score': 10}],
#   'name': 'Rohm Thai',
#   'restaurant_id': '40400957'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d26e'),
#   'address': {'building': '27',
#    'coord': [-74.00892689999999, 40.7133533],
#    'street': 'Park Place',
#    'zipcode': '10007'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 12, 11, 0, 0),
#     'grade': 'Z',
#     'score': 15},
#    {'date': datetime.datetime(2014, 4, 10, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2013, 10, 9, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2013, 7, 16, 0, 0), 'grade': 'P', 'score': 5},
#    {'date': datetime.datetime(2012, 7, 16, 0, 0), 'grade': 'A', 'score': 11},
#    {'date': datetime.datetime(2012, 1, 18, 0, 0), 'grade': 'A', 'score': 8}],
#   'name': 'Bangal Curry',
#   'restaurant_id': '40401972'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d2bb'),
#   'address': {'building': '4',
#    'coord': [-73.7822056, 40.6434612],
#    'street': '- Jfk Airport',
#    'zipcode': '11430'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 7, 22, 0, 0),
#     'grade': 'B',
#     'score': 27},
#    {'date': datetime.datetime(2013, 6, 7, 0, 0), 'grade': 'A', 'score': 5},
#    {'date': datetime.datetime(2012, 6, 22, 0, 0), 'grade': 'A', 'score': 2}],
#   'name': 'Air India Lounge',
#   'restaurant_id': '40403419'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d319'),
#   'address': {'building': '117',
#    'coord': [-73.999501, 40.7348987],
#    'street': 'West   10 Street',
#    'zipcode': '10011'},
#   'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2014, 12, 1, 0, 0),
#     'grade': 'B',
#     'score': 19},
#    {'date': datetime.datetime(2014, 6, 30, 0, 0), 'grade': 'B', 'score': 19},
#    {'date': datetime.datetime(2014, 6, 9, 0, 0), 'grade': 'P', 'score': 3},
#    {'date': datetime.datetime(2013, 12, 11, 0, 0), 'grade': 'C', 'score': 33},
#    {'date': datetime.datetime(2013, 4, 17, 0, 0), 'grade': 'C', 'score': 45},
#    {'date': datetime.datetime(2012, 10, 15, 0, 0), 'grade': 'B', 'score': 23},
#    {'date': datetime.datetime(2012, 5, 3, 0, 0), 'grade': 'A', 'score': 11},
#    {'date': datetime.datetime(2011, 12, 19, 0, 0), 'grade': 'C', 'score': 31}],
#   'name': 'Cafe Asean',
#   'restaurant_id': '40510969'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d348'),
#   'address': {'building': '409',
#    'coord': [-73.98021000000001, 40.7423],
#    'street': '3 Avenue',
#    'zipcode': '10016'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 2, 12, 0, 0),
#     'grade': 'A',
#     'score': 8},
#    {'date': datetime.datetime(2013, 5, 29, 0, 0), 'grade': 'A', 'score': 0},
#    {'date': datetime.datetime(2012, 5, 22, 0, 0), 'grade': 'A', 'score': 3},
#    {'date': datetime.datetime(2012, 1, 5, 0, 0), 'grade': 'A', 'score': 4},
#    {'date': datetime.datetime(2011, 5, 18, 0, 0), 'grade': 'B', 'score': 18}],
#   'name': 'Vatan',
#   'restaurant_id': '40513757'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d363'),
#   'address': {'building': '104',
#    'coord': [-73.98302199999999, 40.742313],
#    'street': 'Lexington Avenue',
#    'zipcode': '10016'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 10, 15, 0, 0),
#     'grade': 'A',
#     'score': 9},
#    {'date': datetime.datetime(2013, 9, 25, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2013, 5, 7, 0, 0), 'grade': 'A', 'score': 7},
#    {'date': datetime.datetime(2012, 4, 16, 0, 0), 'grade': 'A', 'score': 2},
#    {'date': datetime.datetime(2011, 11, 28, 0, 0), 'grade': 'B', 'score': 15}],
#   'name': 'Madras Mahal',
#   'restaurant_id': '40519978'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d38a'),
#   'address': {'building': '2628',
#    'coord': [-90.6220568, 37.76564],
#    'street': 'Cedar Street',
#    'zipcode': '10005'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 9, 22, 0, 0),
#     'grade': 'A',
#     'score': 2},
#    {'date': datetime.datetime(2013, 10, 3, 0, 0), 'grade': 'A', 'score': 0},
#    {'date': datetime.datetime(2013, 4, 24, 0, 0), 'grade': 'A', 'score': 4},
#    {'date': datetime.datetime(2012, 2, 9, 0, 0), 'grade': 'A', 'score': 4}],
#   'name': 'Diwan-E-Khaas',
#   'restaurant_id': '40527369'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d399'),
#   'address': {'building': '15403',
#    'coord': [-73.8096901, 40.72001729999999],
#    'street': 'Union Turnpike',
#    'zipcode': '11367'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 12, 1, 0, 0),
#     'grade': 'A',
#     'score': 5},
#    {'date': datetime.datetime(2013, 11, 7, 0, 0), 'grade': 'A', 'score': 3},
#    {'date': datetime.datetime(2012, 9, 12, 0, 0), 'grade': 'A', 'score': 7}],
#   'name': 'Khyber Restaurant',
#   'restaurant_id': '40530409'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d3a7'),
#   'address': {'building': '1237',
#    'coord': [-73.9586465, 40.8097342],
#    'street': 'Amsterdam Avenue',
#    'zipcode': '10027'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 8, 5, 0, 0),
#     'grade': 'A',
#     'score': 10},
#    {'date': datetime.datetime(2014, 2, 5, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 12, 15, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2011, 11, 23, 0, 0), 'grade': 'A', 'score': 12}],
#   'name': 'Ajanta India',
#   'restaurant_id': '40534837'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d3aa'),
#   'address': {'building': '322',
#    'coord': [-73.9874971, 40.7267605],
#    'street': 'East    6 Street',
#    'zipcode': '10003'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 12, 1, 0, 0),
#     'grade': 'A',
#     'score': 12},
#    {'date': datetime.datetime(2014, 3, 25, 0, 0), 'grade': 'B', 'score': 20},
#    {'date': datetime.datetime(2013, 7, 22, 0, 0), 'grade': 'A', 'score': 7},
#    {'date': datetime.datetime(2013, 1, 24, 0, 0), 'grade': 'A', 'score': 4},
#    {'date': datetime.datetime(2012, 4, 17, 0, 0), 'grade': 'A', 'score': 12}],
#   'name': 'Raj Mahal Indian Restaurant',
#   'restaurant_id': '40534870'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d3f3'),
#   'address': {'building': '110',
#    'coord': [-73.98289749999999, 40.7424602],
#    'street': 'Lexington Avenue',
#    'zipcode': '10016'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 1, 9, 0, 0),
#     'grade': 'A',
#     'score': 13},
#    {'date': datetime.datetime(2013, 5, 8, 0, 0), 'grade': 'A', 'score': 6},
#    {'date': datetime.datetime(2012, 10, 9, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2012, 5, 16, 0, 0), 'grade': 'C', 'score': 11}],
#   'name': 'Pongal Indian Cuisine',
#   'restaurant_id': '40544107'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d45b'),
#   'address': {'building': '603',
#    'coord': [-73.93709729999999, 40.8554247],
#    'street': 'Fort Washington Avenue',
#    'zipcode': '10040'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 8, 18, 0, 0),
#     'grade': 'A',
#     'score': 12},
#    {'date': datetime.datetime(2014, 3, 27, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2013, 2, 21, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 8, 27, 0, 0), 'grade': 'A', 'score': 13}],
#   'name': 'Kismat Indian Cuisine',
#   'restaurant_id': '40557912'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d482'),
#   'address': {'building': '88',
#    'coord': [-74.0058365, 40.70910060000001],
#    'street': 'Fulton Street',
#    'zipcode': '10038'},
#   'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2014, 9, 15, 0, 0),
#     'grade': 'B',
#     'score': 23},
#    {'date': datetime.datetime(2014, 3, 24, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2013, 6, 3, 0, 0), 'grade': 'B', 'score': 27},
#    {'date': datetime.datetime(2012, 10, 23, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 9, 26, 0, 0), 'grade': 'P', 'score': 9},
#    {'date': datetime.datetime(2012, 5, 8, 0, 0), 'grade': 'A', 'score': 13}],
#   'name': "Bennie'S Thai Cafe",
#   'restaurant_id': '40557279'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d495'),
#   'address': {'building': '37',
#    'coord': [-73.990855, 40.737009],
#    'street': 'Union Square West',
#    'zipcode': '10003'},
#   'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2014, 10, 27, 0, 0),
#     'grade': 'A',
#     'score': 12},
#    {'date': datetime.datetime(2013, 10, 10, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2013, 5, 16, 0, 0), 'grade': 'C', 'score': 37},
#    {'date': datetime.datetime(2012, 9, 19, 0, 0), 'grade': 'A', 'score': 10},
#    {'date': datetime.datetime(2012, 2, 7, 0, 0), 'grade': 'A', 'score': 12}],
#   'name': 'Republic Restaurant',
#   'restaurant_id': '40563526'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d4d4'),
#   'address': {'building': '257-05',
#    'coord': [-73.7142688, 40.7458682],
#    'street': 'Union Turnpike',
#    'zipcode': '11004'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2015, 1, 7, 0, 0),
#     'grade': 'Z',
#     'score': 24},
#    {'date': datetime.datetime(2014, 6, 30, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2014, 1, 29, 0, 0), 'grade': 'A', 'score': 11},
#    {'date': datetime.datetime(2013, 6, 22, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2013, 1, 3, 0, 0), 'grade': 'C', 'score': 49},
#    {'date': datetime.datetime(2012, 5, 3, 0, 0), 'grade': 'B', 'score': 16},
#    {'date': datetime.datetime(2012, 4, 20, 0, 0), 'grade': 'P', 'score': 5}],
#   'name': 'Santoor Indian Restaurant',
#   'restaurant_id': '40571663'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d5bd'),
#   'address': {'building': '53',
#    'coord': [-74.0091352, 40.7090346],
#    'street': 'Nassau Street',
#    'zipcode': '10005'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 3, 19, 0, 0),
#     'grade': 'A',
#     'score': 2},
#    {'date': datetime.datetime(2013, 2, 26, 0, 0), 'grade': 'A', 'score': 3},
#    {'date': datetime.datetime(2011, 12, 2, 0, 0), 'grade': 'A', 'score': 10},
#    {'date': datetime.datetime(2011, 7, 11, 0, 0), 'grade': 'A', 'score': 4}],
#   'name': 'Diwan-E- Khaas',
#   'restaurant_id': '40598366'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d5c6'),
#   'address': {'building': '2906',
#    'coord': [-73.92431599999999, 40.75651879999999],
#    'street': '36 Avenue',
#    'zipcode': '11106'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 9, 11, 0, 0),
#     'grade': 'A',
#     'score': 11},
#    {'date': datetime.datetime(2013, 10, 1, 0, 0), 'grade': 'A', 'score': 8},
#    {'date': datetime.datetime(2012, 10, 23, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2011, 10, 28, 0, 0), 'grade': 'A', 'score': 10}],
#   'name': 'Aladdin',
#   'restaurant_id': '40601254'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d622'),
#   'address': {'building': '8306',
#    'coord': [-73.82961499999999, 40.708951],
#    'street': 'Austin Street',
#    'zipcode': '11415'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 2, 8, 0, 0),
#     'grade': 'A',
#     'score': 12},
#    {'date': datetime.datetime(2013, 7, 24, 0, 0), 'grade': 'A', 'score': 7},
#    {'date': datetime.datetime(2012, 12, 18, 0, 0), 'grade': 'A', 'score': 7},
#    {'date': datetime.datetime(2012, 6, 6, 0, 0), 'grade': 'A', 'score': 11}],
#   'name': 'Mehak',
#   'restaurant_id': '40615240'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d6a0'),
#   'address': {'building': '3747',
#    'coord': [-73.8913291, 40.7477727],
#    'street': '74 Street',
#    'zipcode': '11372'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 8, 27, 0, 0),
#     'grade': 'B',
#     'score': 16},
#    {'date': datetime.datetime(2013, 12, 9, 0, 0), 'grade': 'B', 'score': 17},
#    {'date': datetime.datetime(2013, 6, 6, 0, 0), 'grade': 'B', 'score': 19},
#    {'date': datetime.datetime(2012, 12, 6, 0, 0), 'grade': 'C', 'score': 0},
#    {'date': datetime.datetime(2012, 5, 23, 0, 0), 'grade': 'B', 'score': 22},
#    {'date': datetime.datetime(2011, 10, 27, 0, 0), 'grade': 'B', 'score': 23}],
#   'name': 'Jackson Diner Indian Cuisine',
#   'restaurant_id': '40647953'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d705'),
#   'address': {'building': '706-8',
#    'coord': [-73.9714858, 40.793109],
#    'street': 'Amsterdam Avenue',
#    'zipcode': '10025'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 7, 21, 0, 0),
#     'grade': 'A',
#     'score': 5},
#    {'date': datetime.datetime(2013, 6, 13, 0, 0), 'grade': 'A', 'score': 11},
#    {'date': datetime.datetime(2012, 12, 27, 0, 0), 'grade': 'A', 'score': 10},
#    {'date': datetime.datetime(2012, 2, 2, 0, 0), 'grade': 'B', 'score': 17}],
#   'name': 'Ayurveda Cafe',
#   'restaurant_id': '40666541'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d72b'),
#   'address': {'building': '5',
#    'coord': [-73.98641099999999, 40.746979],
#    'street': 'West   31 Street',
#    'zipcode': '10001'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 9, 9, 0, 0),
#     'grade': 'A',
#     'score': 9},
#    {'date': datetime.datetime(2014, 4, 8, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2013, 10, 3, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2013, 4, 23, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2012, 6, 28, 0, 0), 'grade': 'B', 'score': 27},
#    {'date': datetime.datetime(2012, 1, 30, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2011, 10, 3, 0, 0), 'grade': 'B', 'score': 25}],
#   'name': 'Minar Indian Restaurant',
#   'restaurant_id': '40672926'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d7a4'),
#   'address': {'building': '283',
#    'coord': [-74.0032824, 40.7319341],
#    'street': 'Bleecker Street',
#    'zipcode': '10014'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 7, 31, 0, 0),
#     'grade': 'A',
#     'score': 9},
#    {'date': datetime.datetime(2013, 7, 30, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2013, 3, 6, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 7, 12, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 2, 10, 0, 0), 'grade': 'B', 'score': 14},
#    {'date': datetime.datetime(2011, 9, 21, 0, 0), 'grade': 'A', 'score': 10}],
#   'name': 'Ghandi Cafe',
#   'restaurant_id': '40703670'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d7ae'),
#   'address': {'building': '4231',
#    'coord': [-73.7698111, 40.7618378],
#    'street': 'Bell Boulevard',
#    'zipcode': '11361'},
#   'borough': 'Queens',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2014, 11, 26, 0, 0),
#     'grade': 'Z',
#     'score': 23},
#    {'date': datetime.datetime(2014, 1, 23, 0, 0), 'grade': 'A', 'score': 3},
#    {'date': datetime.datetime(2013, 4, 9, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 9, 27, 0, 0), 'grade': 'C', 'score': 38}],
#   'name': 'Erawan Thai Cuisine',
#   'restaurant_id': '40704155'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d805'),
#   'address': {'building': '4563',
#    'coord': [-73.816634, 40.7524508],
#    'street': 'Bowne Street',
#    'zipcode': '11355'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2015, 1, 7, 0, 0),
#     'grade': 'A',
#     'score': 3},
#    {'date': datetime.datetime(2014, 8, 4, 0, 0), 'grade': 'A', 'score': 11},
#    {'date': datetime.datetime(2013, 12, 9, 0, 0), 'grade': 'B', 'score': 19},
#    {'date': datetime.datetime(2013, 6, 28, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2012, 6, 12, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2012, 1, 18, 0, 0), 'grade': 'A', 'score': 11}],
#   'name': 'Dosa Hutt',
#   'restaurant_id': '40718547'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d827'),
#   'address': {'building': '1845',
#    'coord': [-73.9825829, 40.769461],
#    'street': 'Broadway',
#    'zipcode': '10023'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 8, 30, 0, 0),
#     'grade': 'A',
#     'score': 13},
#    {'date': datetime.datetime(2014, 3, 27, 0, 0), 'grade': 'C', 'score': 36},
#    {'date': datetime.datetime(2013, 6, 10, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 3, 12, 0, 0), 'grade': 'A', 'score': 13}],
#   'name': 'Sapphire Indian Cuisine',
#   'restaurant_id': '40722258'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d84f'),
#   'address': {'building': '1185',
#    'coord': [-73.9824347, 40.7578271],
#    'street': 'Avenue Of Americas',
#    'zipcode': '10036'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 12, 11, 0, 0),
#     'grade': 'A',
#     'score': 12},
#    {'date': datetime.datetime(2013, 10, 15, 0, 0), 'grade': 'A', 'score': 8},
#    {'date': datetime.datetime(2013, 5, 3, 0, 0), 'grade': 'A', 'score': 11},
#    {'date': datetime.datetime(2012, 8, 16, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 3, 8, 0, 0), 'grade': 'A', 'score': 12}],
#   'name': 'Utsav Festive India Restaurant',
#   'restaurant_id': '40727750'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d91a'),
#   'address': {'building': '63-108',
#    'coord': [-73.8671967, 40.7216631],
#    'street': 'Woodhaven Boulevard',
#    'zipcode': '11374'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 2, 22, 0, 0),
#     'grade': 'A',
#     'score': 10},
#    {'date': datetime.datetime(2013, 5, 2, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 6, 14, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2011, 12, 15, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2011, 7, 12, 0, 0), 'grade': 'C', 'score': 30}],
#   'name': 'Maurya Restaurant',
#   'restaurant_id': '40754126'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d926'),
#   'address': {'building': '7315',
#    'coord': [-74.0271258, 40.6323596],
#    'street': '3 Avenue',
#    'zipcode': '11209'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 12, 10, 0, 0),
#     'grade': 'A',
#     'score': 5},
#    {'date': datetime.datetime(2013, 11, 27, 0, 0), 'grade': 'A', 'score': 11},
#    {'date': datetime.datetime(2013, 6, 12, 0, 0), 'grade': 'A', 'score': 7},
#    {'date': datetime.datetime(2012, 10, 16, 0, 0), 'grade': 'A', 'score': 8},
#    {'date': datetime.datetime(2012, 4, 16, 0, 0), 'grade': 'A', 'score': 10}],
#   'name': 'Taj Mahal Indian Restaurant',
#   'restaurant_id': '40756209'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d9ad'),
#   'address': {'building': '',
#    'coord': [-73.97705599999999, 40.752998],
#    'street': 'Grand Central Terminal',
#    'zipcode': '10017'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 5, 19, 0, 0),
#     'grade': 'A',
#     'score': 9},
#    {'date': datetime.datetime(2013, 12, 11, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2013, 6, 5, 0, 0), 'grade': 'A', 'score': 11},
#    {'date': datetime.datetime(2012, 4, 30, 0, 0), 'grade': 'A', 'score': 10},
#    {'date': datetime.datetime(2011, 12, 19, 0, 0), 'grade': 'A', 'score': 10},
#    {'date': datetime.datetime(2011, 6, 15, 0, 0), 'grade': 'B', 'score': 16}],
#   'name': 'Cafe Spice',
#   'restaurant_id': '40793607'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d9b7'),
#   'address': {'building': '310',
#    'coord': [-73.9881162, 40.7269427],
#    'street': 'East    6 Street',
#    'zipcode': '10003'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 6, 3, 0, 0),
#     'grade': 'A',
#     'score': 5},
#    {'date': datetime.datetime(2013, 10, 18, 0, 0), 'grade': 'A', 'score': 7},
#    {'date': datetime.datetime(2013, 2, 12, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2011, 10, 25, 0, 0), 'grade': 'A', 'score': 2}],
#   'name': 'Taj Cafe',
#   'restaurant_id': '40793198'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d9cc'),
#   'address': {'building': '215',
#    'coord': [-73.9935596, 40.6866665],
#    'street': 'Court Street',
#    'zipcode': '11201'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2014, 9, 26, 0, 0),
#     'grade': 'A',
#     'score': 11},
#    {'date': datetime.datetime(2014, 4, 16, 0, 0), 'grade': 'B', 'score': 23},
#    {'date': datetime.datetime(2013, 3, 2, 0, 0), 'grade': 'A', 'score': 10},
#    {'date': datetime.datetime(2012, 8, 22, 0, 0), 'grade': 'A', 'score': 6},
#    {'date': datetime.datetime(2012, 1, 25, 0, 0), 'grade': 'A', 'score': 6}],
#   'name': 'Joya',
#   'restaurant_id': '40799210'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408d9e3'),
#   'address': {'building': '68',
#    'coord': [-73.9968939, 40.7236789],
#    'street': 'Prince Street',
#    'zipcode': '10012'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 4, 25, 0, 0),
#     'grade': 'A',
#     'score': 7},
#    {'date': datetime.datetime(2013, 4, 10, 0, 0), 'grade': 'A', 'score': 7},
#    {'date': datetime.datetime(2012, 3, 14, 0, 0), 'grade': 'A', 'score': 8},
#    {'date': datetime.datetime(2011, 8, 12, 0, 0), 'grade': 'A', 'score': 12}],
#   'name': 'Hampton Chutney Company',
#   'restaurant_id': '40802900'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408da05'),
#   'address': {'building': '87-46',
#    'coord': [-73.8030423, 40.7081423],
#    'street': 'Parsons Boulevard',
#    'zipcode': '11432'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 9, 24, 0, 0),
#     'grade': 'Z',
#     'score': 22},
#    {'date': datetime.datetime(2014, 5, 15, 0, 0), 'grade': 'A', 'score': 10},
#    {'date': datetime.datetime(2013, 11, 13, 0, 0), 'grade': 'A', 'score': 7},
#    {'date': datetime.datetime(2013, 5, 31, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 12, 20, 0, 0), 'grade': 'A', 'score': 10},
#    {'date': datetime.datetime(2011, 11, 23, 0, 0), 'grade': 'A', 'score': 13}],
#   'name': 'Al-Mehran Restaurant',
#   'restaurant_id': '40810032'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408da61'),
#   'address': {'building': '3725',
#    'coord': [-73.8914324, 40.7482588],
#    'street': '74 Street',
#    'zipcode': '11372'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 4, 25, 0, 0),
#     'grade': 'A',
#     'score': 12},
#    {'date': datetime.datetime(2013, 9, 18, 0, 0), 'grade': 'A', 'score': 10},
#    {'date': datetime.datetime(2013, 2, 12, 0, 0), 'grade': 'B', 'score': 15},
#    {'date': datetime.datetime(2012, 7, 17, 0, 0), 'grade': 'A', 'score': 7},
#    {'date': datetime.datetime(2012, 7, 5, 0, 0), 'grade': 'P', 'score': 13},
#    {'date': datetime.datetime(2012, 2, 8, 0, 0), 'grade': 'B', 'score': 19}],
#   'name': 'Indian Taj',
#   'restaurant_id': '40827157'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408da66'),
#   'address': {'building': '34-14',
#    'coord': [-73.91863839999999, 40.7653613],
#    'street': '30 Avenue',
#    'zipcode': '11103'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 8, 19, 0, 0),
#     'grade': 'A',
#     'score': 5},
#    {'date': datetime.datetime(2014, 1, 29, 0, 0), 'grade': 'A', 'score': 10},
#    {'date': datetime.datetime(2012, 12, 31, 0, 0), 'grade': 'A', 'score': 10},
#    {'date': datetime.datetime(2012, 7, 12, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2011, 11, 23, 0, 0), 'grade': 'A', 'score': 9}],
#   'name': 'Gandhi Indian Cuisine',
#   'restaurant_id': '40827726'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408da7f'),
#   'address': {'building': '45-57',
#    'coord': [-73.8169913, 40.7528258],
#    'street': 'Bowne Street',
#    'zipcode': '11355'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 4, 23, 0, 0),
#     'grade': 'A',
#     'score': 13},
#    {'date': datetime.datetime(2013, 3, 28, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 10, 26, 0, 0), 'grade': 'A', 'score': 5},
#    {'date': datetime.datetime(2012, 3, 9, 0, 0), 'grade': 'B', 'score': 17},
#    {'date': datetime.datetime(2011, 10, 27, 0, 0), 'grade': 'B', 'score': 23}],
#   'name': 'Devasthanam Canteen',
#   'restaurant_id': '40835821'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408da80'),
#   'address': {'building': '73-10',
#    'coord': [-73.8923799, 40.7488892],
#    'street': '37 Avenue',
#    'zipcode': '11372'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2015, 1, 6, 0, 0),
#     'grade': 'Z',
#     'score': 18},
#    {'date': datetime.datetime(2014, 7, 9, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2014, 1, 31, 0, 0), 'grade': 'A', 'score': 5},
#    {'date': datetime.datetime(2013, 8, 23, 0, 0), 'grade': 'A', 'score': 7},
#    {'date': datetime.datetime(2013, 3, 20, 0, 0), 'grade': 'C', 'score': 33},
#    {'date': datetime.datetime(2012, 9, 25, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 4, 17, 0, 0), 'grade': 'A', 'score': 13}],
#   'name': 'Maharaja Quality Sweets',
#   'restaurant_id': '40836314'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408db5f'),
#   'address': {'building': '138',
#    'coord': [-73.98397539999999, 40.75796880000001],
#    'street': 'West 46 Street',
#    'zipcode': '10036'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 10, 30, 0, 0),
#     'grade': 'A',
#     'score': 7},
#    {'date': datetime.datetime(2014, 4, 14, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2013, 3, 22, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 8, 23, 0, 0), 'grade': 'C', 'score': 60},
#    {'date': datetime.datetime(2012, 3, 19, 0, 0), 'grade': 'A', 'score': 9}],
#   'name': 'Minar Indian Restaurant',
#   'restaurant_id': '40871006'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408db68'),
#   'address': {'building': '813',
#    'coord': [-73.9875078, 40.7659352],
#    'street': '9 Avenue',
#    'zipcode': '10019'},
#   'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2015, 1, 9, 0, 0),
#     'grade': 'A',
#     'score': 7},
#    {'date': datetime.datetime(2014, 7, 10, 0, 0), 'grade': 'A', 'score': 11},
#    {'date': datetime.datetime(2014, 1, 16, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2013, 5, 13, 0, 0), 'grade': 'B', 'score': 19},
#    {'date': datetime.datetime(2012, 4, 3, 0, 0), 'grade': 'A', 'score': 9}],
#   'name': 'Wondee Siam Ii',
#   'restaurant_id': '40871795'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408dbad'),
#   'address': {'building': '970',
#    'coord': [-73.9542902, 40.7322304],
#    'street': 'Manhattan Avenue',
#    'zipcode': '11222'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2014, 1, 23, 0, 0),
#     'grade': 'A',
#     'score': 12},
#    {'date': datetime.datetime(2013, 8, 29, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 8, 21, 0, 0), 'grade': 'A', 'score': 11},
#    {'date': datetime.datetime(2012, 3, 30, 0, 0), 'grade': 'C', 'score': 35},
#    {'date': datetime.datetime(2011, 4, 7, 0, 0), 'grade': 'A', 'score': 9}],
#   'name': 'Ott Thai Cuisine',
#   'restaurant_id': '40880867'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408dbd4'),
#   'address': {'building': '246',
#    'coord': [-73.96878889999999, 40.7554855],
#    'street': 'East   51 Street',
#    'zipcode': '10022'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 11, 12, 0, 0),
#     'grade': 'A',
#     'score': 8},
#    {'date': datetime.datetime(2014, 3, 25, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2013, 6, 24, 0, 0), 'grade': 'B', 'score': 18},
#    {'date': datetime.datetime(2013, 6, 11, 0, 0), 'grade': 'P', 'score': 5},
#    {'date': datetime.datetime(2012, 6, 19, 0, 0), 'grade': 'A', 'score': 10},
#    {'date': datetime.datetime(2011, 12, 14, 0, 0), 'grade': 'B', 'score': 18}],
#   'name': 'Amma',
#   'restaurant_id': '40885805'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408dc19'),
#   'address': {'building': '99',
#    'coord': [-74.0010291, 40.7296283],
#    'street': 'Mac Dougal Street',
#    'zipcode': '10012'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 6, 26, 0, 0),
#     'grade': 'B',
#     'score': 20},
#    {'date': datetime.datetime(2013, 4, 22, 0, 0), 'grade': 'A', 'score': 7},
#    {'date': datetime.datetime(2012, 4, 4, 0, 0), 'grade': 'A', 'score': 9}],
#   'name': 'The Kati Roll Company',
#   'restaurant_id': '40901527'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408dc29'),
#   'address': {'building': '196',
#    'coord': [-73.99424800000001, 40.721761],
#    'street': 'Elizabeth Street',
#    'zipcode': '10012'},
#   'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2014, 6, 18, 0, 0),
#     'grade': 'A',
#     'score': 11},
#    {'date': datetime.datetime(2013, 6, 19, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2013, 1, 11, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2012, 4, 6, 0, 0), 'grade': 'A', 'score': 9}],
#   'name': 'Lovely Day',
#   'restaurant_id': '40904478'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408dc91'),
#   'address': {'building': '114',
#    'coord': [-73.960026, 40.718055],
#    'street': 'North    6 Street',
#    'zipcode': '11249'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2014, 12, 4, 0, 0),
#     'grade': 'A',
#     'score': 4},
#    {'date': datetime.datetime(2014, 4, 16, 0, 0), 'grade': 'B', 'score': 18},
#    {'date': datetime.datetime(2013, 9, 27, 0, 0), 'grade': 'B', 'score': 20},
#    {'date': datetime.datetime(2013, 4, 17, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 8, 27, 0, 0), 'grade': 'A', 'score': 10},
#    {'date': datetime.datetime(2011, 12, 7, 0, 0), 'grade': 'A', 'score': 8}],
#   'name': 'Sea',
#   'restaurant_id': '40922618'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408dcbd'),
#   'address': {'building': '301',
#    'coord': [-73.973266, 40.678852],
#    'street': 'Flatbush Avenue',
#    'zipcode': '11217'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 9, 22, 0, 0),
#     'grade': 'A',
#     'score': 11},
#    {'date': datetime.datetime(2014, 4, 1, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2013, 7, 18, 0, 0), 'grade': 'A', 'score': 7},
#    {'date': datetime.datetime(2012, 9, 13, 0, 0), 'grade': 'B', 'score': 22},
#    {'date': datetime.datetime(2012, 4, 16, 0, 0), 'grade': 'C', 'score': 45},
#    {'date': datetime.datetime(2011, 9, 29, 0, 0), 'grade': 'B', 'score': 17}],
#   'name': 'Joy Indian Restaurant',
#   'restaurant_id': '40928416'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408dcf9'),
#   'address': {'building': '177',
#    'coord': [-74.00191559999999, 40.7264308],
#    'street': 'Prince Street',
#    'zipcode': '10012'},
#   'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2015, 1, 13, 0, 0),
#     'grade': 'A',
#     'score': 9},
#    {'date': datetime.datetime(2014, 1, 2, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2013, 8, 9, 0, 0), 'grade': 'B', 'score': 25},
#    {'date': datetime.datetime(2013, 3, 29, 0, 0), 'grade': 'C', 'score': 13},
#    {'date': datetime.datetime(2012, 6, 20, 0, 0), 'grade': 'A', 'score': 13}],
#   'name': 'Spice',
#   'restaurant_id': '40933887'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408dd0f'),
#   'address': {'building': '329',
#    'coord': [-73.982112, 40.73968600000001],
#    'street': '3 Avenue',
#    'zipcode': '10010'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 7, 1, 0, 0),
#     'grade': 'A',
#     'score': 12},
#    {'date': datetime.datetime(2013, 12, 31, 0, 0), 'grade': 'B', 'score': 25},
#    {'date': datetime.datetime(2013, 5, 15, 0, 0), 'grade': 'B', 'score': 22},
#    {'date': datetime.datetime(2012, 10, 15, 0, 0), 'grade': 'B', 'score': 14},
#    {'date': datetime.datetime(2012, 9, 12, 0, 0), 'grade': 'P', 'score': 3},
#    {'date': datetime.datetime(2011, 9, 1, 0, 0), 'grade': 'A', 'score': 11}],
#   'name': "Baluchi'S",
#   'restaurant_id': '40936006'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408dd6f'),
#   'address': {'building': '148',
#    'coord': [-73.973626, 40.7535539],
#    'street': 'East 46 Street',
#    'zipcode': '10017'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2015, 1, 8, 0, 0),
#     'grade': 'A',
#     'score': 10},
#    {'date': datetime.datetime(2014, 8, 21, 0, 0), 'grade': 'B', 'score': 16},
#    {'date': datetime.datetime(2014, 2, 10, 0, 0), 'grade': 'A', 'score': 8},
#    {'date': datetime.datetime(2013, 8, 9, 0, 0), 'grade': 'A', 'score': 2},
#    {'date': datetime.datetime(2012, 12, 24, 0, 0), 'grade': 'A', 'score': 5},
#    {'date': datetime.datetime(2012, 7, 17, 0, 0), 'grade': 'A', 'score': 11},
#    {'date': datetime.datetime(2012, 2, 10, 0, 0), 'grade': 'A', 'score': 13}],
#   'name': 'Joy Curry & Tandoor',
#   'restaurant_id': '40946298'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408dd7f'),
#   'address': {'building': '1',
#    'coord': [-73.8491683, 40.7599407],
#    'street': 'Worlds Fair Marina',
#    'zipcode': '11368'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 6, 20, 0, 0),
#     'grade': 'A',
#     'score': 10},
#    {'date': datetime.datetime(2013, 5, 24, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 12, 12, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 9, 24, 0, 0), 'grade': 'P', 'score': 9},
#    {'date': datetime.datetime(2012, 2, 27, 0, 0), 'grade': 'A', 'score': 2},
#    {'date': datetime.datetime(2011, 8, 18, 0, 0), 'grade': 'A', 'score': 11}],
#   'name': 'World Fair Marina Restaurant & Banquet',
#   'restaurant_id': '40947943'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408dd98'),
#   'address': {'building': '142',
#    'coord': [-73.99050510000001, 40.6870239],
#    'street': 'Smith Street',
#    'zipcode': '11201'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 12, 10, 0, 0),
#     'grade': 'A',
#     'score': 11},
#    {'date': datetime.datetime(2014, 3, 4, 0, 0), 'grade': 'A', 'score': 11},
#    {'date': datetime.datetime(2013, 9, 5, 0, 0), 'grade': 'B', 'score': 27},
#    {'date': datetime.datetime(2013, 6, 25, 0, 0), 'grade': 'P', 'score': 9},
#    {'date': datetime.datetime(2012, 7, 5, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2011, 12, 14, 0, 0), 'grade': 'B', 'score': 22}],
#   'name': 'Britain Indian Restaurant',
#   'restaurant_id': '40944839'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408ddcb'),
#   'address': {'building': '113',
#    'coord': [-73.98879389999999, 40.7194443],
#    'street': 'Ludlow Street',
#    'zipcode': '10002'},
#   'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2014, 12, 9, 0, 0),
#     'grade': 'A',
#     'score': 10},
#    {'date': datetime.datetime(2014, 4, 29, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2013, 10, 8, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2013, 3, 26, 0, 0), 'grade': 'A', 'score': 13},
#    {'date': datetime.datetime(2012, 6, 13, 0, 0), 'grade': 'B', 'score': 14},
#    {'date': datetime.datetime(2012, 1, 17, 0, 0), 'grade': 'C', 'score': 32}],
#   'name': 'Kuma Inn',
#   'restaurant_id': '40957398'},
#  {'_id': ObjectId('626675ec1b3fa6fbc408de12'),
#   'address': {'building': '106',
#    'coord': [-73.9998681, 40.7162087],
#    'street': 'Bayard Street',
#    'zipcode': '10013'},
#   'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2014, 10, 8, 0, 0),
#     'grade': 'A',
#     'score': 12},
#    {'date': datetime.datetime(2014, 5, 7, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2013, 9, 24, 0, 0), 'grade': 'A', 'score': 9},
#    {'date': datetime.datetime(2013, 4, 12, 0, 0), 'grade': 'A', 'score': 12},
# ...
#   'address': {'building': '71',
#    'coord': [-73.98720999999999, 40.72553],
#    'street': '1 Avenue',
#    'zipcode': '10003'},
#   'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2014, 9, 15, 0, 0),
#     'grade': 'A',
#     'score': 2}],
#   'name': 'Thamma',
#   'restaurant_id': '50011657'},
#  {'_id': ObjectId('626675ed1b3fa6fbc40926d4'),
#   'address': {'building': '70-74',
#    'coord': [-73.8151755, 40.7299107],
#    'street': 'Kissena Boulevard',
#    'zipcode': '11367'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 11, 7, 0, 0),
#     'grade': 'A',
#     'score': 9}],
#   'name': 'Indochi Fusion Cuisine',
#   'restaurant_id': '50011749'},
#  {'_id': ObjectId('626675ed1b3fa6fbc40926e5'),
#   'address': {'building': '311',
#    'coord': [-73.9809902, 40.6672747],
#    'street': '7Th Ave',
#    'zipcode': '11215'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2014, 8, 13, 0, 0),
#     'grade': 'C',
#     'score': 19}],
#   'name': 'Rice Thai Kitchen',
#   'restaurant_id': '50011817'},
#  {'_id': ObjectId('626675ed1b3fa6fbc40926f8'),
#   'address': {'building': '99',
#    'coord': [-73.988978, 40.727377],
#    'street': '2 Avenue',
#    'zipcode': '10003'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 9, 15, 0, 0),
#     'grade': 'A',
#     'score': 3}],
#   'name': 'Bricklane Curry House',
#   'restaurant_id': '50011919'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092772'),
#   'address': {'building': '135-08',
#    'coord': [-73.8115541, 40.6916918],
#    'street': 'Liberty Avenue',
#    'zipcode': '11419'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 8, 13, 0, 0),
#     'grade': 'A',
#     'score': 12}],
#   'name': 'Indian Diner',
#   'restaurant_id': '50012295'},
#  {'_id': ObjectId('626675ed1b3fa6fbc40927e0'),
#   'address': {'building': '216',
#    'coord': [-73.98534699999999, 40.736252],
#    'street': '3 Avenue',
#    'zipcode': '10003'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 10, 14, 0, 0),
#     'grade': 'A',
#     'score': 10}],
#   'name': 'A Spice Lane',
#   'restaurant_id': '50012690'},
#  {'_id': ObjectId('626675ed1b3fa6fbc40927e2'),
#   'address': {'building': '8110',
#    'coord': [-73.88144419999999, 40.742168],
#    'street': 'Broadway',
#    'zipcode': '11373'},
#   'borough': 'Queens',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2014, 11, 17, 0, 0),
#     'grade': 'A',
#     'score': 8}],
#   'name': '8 Paet Rio',
#   'restaurant_id': '50012722'},
#  {'_id': ObjectId('626675ed1b3fa6fbc40927e9'),
#   'address': {'building': '1961',
#    'coord': [-73.935937, 40.622162],
#    'street': 'Flatbush Avenue',
#    'zipcode': '11234'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 8, 13, 0, 0),
#     'grade': 'A',
#     'score': 12}],
#   'name': 'Agra King Restaurant',
#   'restaurant_id': '50012743'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092861'),
#   'address': {'building': '311',
#    'coord': [-73.9618969, 40.7133185],
#    'street': 'Bedford Avenue',
#    'zipcode': '11211'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2014, 10, 15, 0, 0),
#     'grade': 'B',
#     'score': 19}],
#   'name': 'Khao Sarn',
#   'restaurant_id': '50013241'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092874'),
#   'address': {'building': '6',
#    'coord': [-73.98380399999999, 40.72102599999999],
#    'street': 'Clinton Street',
#    'zipcode': '10002'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 10, 9, 0, 0),
#     'grade': 'A',
#     'score': 9}],
#   'name': 'Khushboo Indian Restaurant',
#   'restaurant_id': '50013373'},
#  {'_id': ObjectId('626675ed1b3fa6fbc40928a9'),
#   'address': {'building': '3682B',
#    'coord': [-73.940978, 40.5942756],
#    'street': 'Nostrand Ave',
#    'zipcode': '11229'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2014, 8, 25, 0, 0),
#     'grade': 'A',
#     'score': 9}],
#   'name': 'Thai Basil',
#   'restaurant_id': '50013579'},
#  {'_id': ObjectId('626675ed1b3fa6fbc40928bf'),
#   'address': {'building': '33-47',
#    'coord': [-73.78936500000002, 40.766316],
#    'street': 'Francis Lewis Boulevard',
#    'zipcode': '11358'},
#   'borough': 'Queens',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2014, 11, 26, 0, 0),
#     'grade': 'A',
#     'score': 12}],
#   'name': 'Thanya Thai Cuisine',
#   'restaurant_id': '50013673'},
#  {'_id': ObjectId('626675ed1b3fa6fbc40928e2'),
#   'address': {'building': '45-04',
#    'coord': [-73.9194626, 40.7430854],
#    'street': 'Queens Boulevard',
#    'zipcode': '11104'},
#   'borough': 'Queens',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2014, 11, 21, 0, 0),
#     'grade': 'A',
#     'score': 13}],
#   'name': 'Blu  Orchid Restaurant',
#   'restaurant_id': '50013819'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092918'),
#   'address': {'building': '180-10',
#    'coord': [-73.7876884, 40.7269966],
#    'street': 'Union Turnpike',
#    'zipcode': '11366'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 12, 11, 0, 0),
#     'grade': 'A',
#     'score': 6}],
#   'name': "Dhruv'S Kati Shack Factory",
#   'restaurant_id': '50014020'},
#  {'_id': ObjectId('626675ed1b3fa6fbc409293a'),
#   'address': {'building': '243-08',
#    'coord': [-73.7261903, 40.7408608],
#    'street': 'Union Turnpike',
#    'zipcode': '11426'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 12, 1, 0, 0),
#     'grade': 'Z',
#     'score': 26}],
#   'name': 'Sohna Punjab Indian Restaurant',
#   'restaurant_id': '50014166'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092959'),
#   'address': {'building': '980',
#    'coord': [-73.916853, 40.8284184],
#    'street': 'Morris Avenue',
#    'zipcode': '10456'},
#   'borough': 'Bronx',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 9, 30, 0, 0),
#     'grade': 'A',
#     'score': 11}],
#   'name': 'Hungry Bird',
#   'restaurant_id': '50014239'},
#  {'_id': ObjectId('626675ed1b3fa6fbc40929c9'),
#   'address': {'building': '57-17',
#    'coord': [-73.9070043, 40.7455382],
#    'street': 'Roosevelt Avenue',
#    'zipcode': '11377'},
#   'borough': 'Queens',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2014, 9, 17, 0, 0),
#     'grade': 'A',
#     'score': 4}],
#   'name': 'Chin Chin Thai Kitchen',
#   'restaurant_id': '50014560'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092a53'),
#   'address': {'building': '595',
#    'coord': [-73.96386679999999, 40.6797842],
#    'street': 'Washington Avenue',
#    'zipcode': '11238'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2015, 1, 20, 0, 0),
#     'grade': 'Not Yet Graded',
#     'score': 40}],
#   'name': 'Tumdri',
#   'restaurant_id': '50015043'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092a60'),
#   'address': {'building': '37',
#    'coord': [-73.9821244, 40.7551156],
#    'street': 'West   43 Street',
#    'zipcode': '10036'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 10, 27, 0, 0),
#     'grade': 'A',
#     'score': 7}],
#   'name': "Baluchi'S Fresh",
#   'restaurant_id': '50015083'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092a7f'),
#   'address': {'building': '54',
#    'coord': [-73.97458200000001, 40.6760504],
#    'street': '7 Avenue',
#    'zipcode': '11217'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 10, 22, 0, 0),
#     'grade': 'A',
#     'score': 7}],
#   'name': 'Tikka Grill',
#   'restaurant_id': '50015168'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092abe'),
#   'address': {'building': '690',
#    'coord': [-73.98979, 40.761764],
#    'street': '9 Avenue',
#    'zipcode': '10036'},
#   'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2014, 9, 23, 0, 0),
#     'grade': 'A',
#     'score': 10}],
#   'name': 'Room Service',
#   'restaurant_id': '50015344'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092ac9'),
#   'address': {'building': '637',
#    'coord': [-73.9758301, 40.7453788],
#    'street': '2 Avenue',
#    'zipcode': '10016'},
#   'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2014, 12, 1, 0, 0),
#     'grade': 'A',
#     'score': 10}],
#   'name': 'Lan Larb',
#   'restaurant_id': '50015399'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092ad0'),
#   'address': {'building': '227',
#    'coord': [-73.9985675, 40.7200616],
#    'street': 'Centre Street',
#    'zipcode': '10013'},
#   'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2014, 12, 22, 0, 0),
#     'grade': 'Z',
#     'score': 19}],
#   'name': 'Lan Larb Soho',
#   'restaurant_id': '50015395'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092b03'),
#   'address': {'building': '63-108',
#    'coord': [-73.8671967, 40.7216631],
#    'street': 'Woodhaven Boulevard',
#    'zipcode': '11374'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 11, 18, 0, 0),
#     'grade': 'Z',
#     'score': 27}],
#   'name': 'Mayurya Banquet Hall & Restaurant',
#   'restaurant_id': '50015517'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092b10'),
#   'address': {'building': '1393A',
#    'coord': [-73.9582662, 40.7692944],
#    'street': '2Nd Ave',
#    'zipcode': '10021'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 12, 17, 0, 0),
#     'grade': 'A',
#     'score': 9}],
#   'name': 'Rongoli Exquiste Indian Cuisine',
#   'restaurant_id': '50015570'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092b25'),
#   'address': {'building': '51-20',
#    'coord': [-73.9126129, 40.745695],
#    'street': 'Skillman Avenue',
#    'zipcode': '11377'},
#   'borough': 'Queens',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2014, 10, 7, 0, 0),
#     'grade': 'A',
#     'score': 9}],
#   'name': 'Thai Pot Bistro',
#   'restaurant_id': '50015647'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092b2e'),
#   'address': {'building': '501B',
#    'coord': [-73.9811696, 40.6856789],
#    'street': 'Atlantic Ave',
#    'zipcode': '11217'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 11, 20, 0, 0),
#     'grade': 'A',
#     'score': 8}],
#   'name': 'Masala Grill',
#   'restaurant_id': '50015676'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092b3b'),
#   'address': {'building': '185',
#    'coord': [-73.94694419999999, 40.727182],
#    'street': 'Norman Avenue',
#    'zipcode': '11222'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 12, 2, 0, 0),
#     'grade': 'A',
#     'score': 12}],
#   'name': 'Moha Rani',
#   'restaurant_id': '50015744'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092b5e'),
#   'address': {'building': '127',
#    'coord': [-74.001325, 40.6872619],
#    'street': 'Columbia St',
#    'zipcode': '11231'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2014, 11, 29, 0, 0),
#     'grade': 'A',
#     'score': 11}],
#   'name': 'Pok Pok Phat Thai',
#   'restaurant_id': '50015836'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092bab'),
#   'address': {'building': '452',
#    'coord': [-73.977251, 40.7850197],
#    'street': 'Amsterdam Avenue',
#    'zipcode': '10024'},
#   'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2015, 1, 20, 0, 0),
#     'grade': 'Not Yet Graded',
#     'score': 12}],
#   'name': 'Senn Thai Comfort Food',
#   'restaurant_id': '50016060'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092c01'),
#   'address': {'building': '447',
#    'coord': [-73.984572, 40.662886],
#    'street': '7Th Ave',
#    'zipcode': '11215'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2015, 1, 7, 0, 0),
#     'grade': 'A',
#     'score': 3}],
#   'name': 'Hua Lumphong',
#   'restaurant_id': '50016286'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092c8f'),
#   'address': {'building': '787',
#    'coord': [-73.9504151, 40.6743447],
#    'street': 'Prospect Place',
#    'zipcode': '11216'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2014, 11, 13, 0, 0),
#     'grade': 'A',
#     'score': 9}],
#   'name': 'Curry Garden',
#   'restaurant_id': '50016742'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092cb4'),
#   'address': {'building': '86-08',
#    'coord': [-73.878691, 40.74168],
#    'street': 'Whitney Avenue',
#    'zipcode': '11373'},
#   'borough': 'Queens',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2015, 1, 20, 0, 0),
#     'grade': 'Not Yet Graded',
#     'score': 9}],
#   'name': 'Plant Love House',
#   'restaurant_id': '50016819'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092d0f'),
#   'address': {'building': '42',
#    'coord': [-73.989121, 40.7362872],
#    'street': 'Union Sq E',
#    'zipcode': '10003'},
#   'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2014, 12, 3, 0, 0),
#     'grade': 'A',
#     'score': 13}],
#   'name': 'Wok To Walk',
#   'restaurant_id': '50017026'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092d4f'),
#   'address': {'building': '116-33',
#    'coord': [-73.8481583, 40.723557],
#    'street': 'Queens Boulevard',
#    'zipcode': '11375'},
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2015, 1, 20, 0, 0),
#     'grade': 'Not Yet Graded',
#     'score': 30}],
#   'name': 'Haveli Fine Indian Cuisine',
#   'restaurant_id': '50017167'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092d7d'),
#   'address': {'building': '443',
#    'coord': [-73.936898, 40.70231],
#    'street': 'Bushwick Ave',
#    'zipcode': '11206'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2015, 1, 7, 0, 0),
#     'grade': 'A',
#     'score': 13}],
#   'name': 'All About Indian Food',
#   'restaurant_id': '50017266'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092dd0'),
#   'address': {'building': '1575',
#    'coord': [-73.948431, 40.788801],
#    'street': 'Lexington Ave',
#    'zipcode': '10029'},
#   'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2015, 1, 20, 0, 0),
#     'grade': 'Not Yet Graded',
#     'score': 8}],
#   'name': 'Koonsup Thai',
#   'restaurant_id': '50017465'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092e51'),
#   'address': {'building': '318',
#    'coord': [-73.9876705, 40.7268324],
#    'street': 'East 6 Street',
#    'zipcode': '10003'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2015, 1, 20, 0, 0),
#     'grade': 'Not Yet Graded',
#     'score': 25}],
#   'name': 'Malai Marke',
#   'restaurant_id': '50017819'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092ecb'),
#   'address': {'building': '396',
#    'coord': [-73.985271, 40.6707256],
#    'street': '5Th Ave',
#    'zipcode': '11215'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2015, 1, 20, 0, 0),
#     'grade': 'Not Yet Graded',
#     'score': 26}],
#   'name': 'New Aarpan',
#   'restaurant_id': '50018087'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092f9b'),
#   'address': {'building': '351',
#    'coord': [-73.9819936, 40.6660587],
#    'street': '7Th Ave',
#    'zipcode': '11215'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Indian',
#   'grades': [{'date': datetime.datetime(2015, 1, 20, 0, 0),
#     'grade': 'Not Yet Graded',
#     'score': 9}],
#   'name': 'Indian Spice',
#   'restaurant_id': '50018514'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4092fb7'),
#   'address': {'building': '409',
#    'coord': [-73.995408, 40.750087],
#    'street': '8Th Ave',
#    'zipcode': '10001'},
#   'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2015, 1, 8, 0, 0),
#     'grade': 'A',
#     'score': 5}],
#   'name': 'Pad Thai',
#   'restaurant_id': '50018581'},
#  {'_id': ObjectId('626675ed1b3fa6fbc4093002'),
#   'address': {'building': '338',
#    'coord': [-73.9626122, 40.7128921],
#    'street': 'Bedford Ave',
#    'zipcode': '11249'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Thai',
#   'grades': [{'date': datetime.datetime(2015, 1, 20, 0, 0),
#     'grade': 'Not Yet Graded',
#     'score': 19}],
#   'name': 'Khao Sarn',
#   'restaurant_id': '50018728'}]

# %% [markdown]
# ### Find a restaurant with the following address: 1115 Rogers Avenue, 11226

# %%
collection.find_one({'address.street': 'Rogers Avenue', 'address.building': '1115', 'address.zipcode': '11226'})
# Out:
# {'_id': ObjectId('626675ec1b3fa6fbc408dfa9'),
#  'address': {'building': '1115',
#   'coord': [-73.9513659, 40.6426492],
#   'street': 'Rogers Avenue',
#   'zipcode': '11226'},
#  'borough': 'Brooklyn',
#  'cuisine': 'Creole',
#  'grades': [{'date': datetime.datetime(2014, 12, 22, 0, 0),
#    'grade': 'A',
#    'score': 10},
#   {'date': datetime.datetime(2014, 8, 5, 0, 0), 'grade': 'A', 'score': 9},
#   {'date': datetime.datetime(2014, 2, 10, 0, 0), 'grade': 'A', 'score': 10},
#   {'date': datetime.datetime(2012, 12, 19, 0, 0), 'grade': 'A', 'score': 11},
#   {'date': datetime.datetime(2011, 12, 30, 0, 0), 'grade': 'A', 'score': 10}],
#  'name': 'Chez Macoule Restaurant',
#  'restaurant_id': '41012277'}

# %% [markdown]
# ## Exercise 2
# Insert into the database following restaurant:
# - Address: 1480 2 Avenue, 10075, -73.9557413, 40.7720266
# - Borough: Manhattan
# - Cuisine: Italian
# - Name: Vella
# - Id: 41704620
# - Grades:
#     - A, 11, 01 Oct, 2014

# %%
import datetime
data = {
    'address': {'building': '1480', 'coord': [-73.9557413, 40.7720266], 'street': '2 Avenue', 'zipcode': '10075'},
    'borough': 'Manhattan', 'cuisine': 'Italian',
    'grades': [{'date': datetime.datetime(2014, 10, 1, 0, 0), 'grade': 'A', 'score': 10}],
    'name': 'Vella', 'restaurant_id': '41704620'}
result = collection.insert_one(data)

# %%
result.inserted_id
# Out:
# ObjectId('62667bc0cae06f3a30e1d4ac')

# %% [markdown]
# ## Exercise 3

# %% [markdown]
# ### Delete from the database a single Manhattan located restaurant

# %%
collection.delete_one({'borough': 'Manhattan'}).raw_result
# Out:
# {'n': 1, 'ok': 1.0}

# %% [markdown]
# ### Delete from the database all Thai cuisines

# %%
collection.delete_many({'cuisine': 'Thai'}).raw_result
# Out:
# {'n': 285, 'ok': 1.0}

# %% [markdown]
# ## Exercise 4
# Query all restaurants on the Rogers Avenue street, for each of them do the following:
# - if it has more than one C grades → delete this restaurant
# - otherwise, add another C grade to this restaurant

# %%
rests_on_street = collection.find({'address.street': 'Rogers Avenue', 'grades.grade': 'C'})

# %%
rests_with_cc = []
for e in rests_on_street:
    c_counter = 0
    for g in e['grades']:
        if g['grade'] == 'C':
            c_counter += 1
    if c_counter > 1:
        collection.delete_one(e)
    else:
        print('add')
        collection.update_one(e, {'$push': {'grades': {'date': datetime.datetime(2014, 10, 1, 0, 0), 'grade': 'C', 'score': 10}}})
        # rests_with_cc.append(e)
